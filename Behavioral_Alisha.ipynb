# %%
import pandas as pd
import numpy as np
hr = pd.read_csv('P:/TYDY/Behavioral_Alisha.csv')

# %%
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import matplotlib
# %matplotlib inline

# %%
import matplotlib.ticker as mtick

# %%
import datetime
from datetime import timedelta
from numpy import nan
from numpy import NaN

# %%
hr.head()
# Out:
#     Age  Gender2 Gender  Department Band  App_Logins  Web_Logins  \
# 0   NaN      NaN    NaN  Healthcare   A1           0           0
# 1   NaN      NaN    NaN  Healthcare   A2           1           0
# 2   NaN      NaN    NaN   Insurance  NaN           1           0
# 3  35.0      0.0   Male     Finance  NaN           3           1
# 4   NaN      NaN    NaN     Finance  NaN           0           2
#
#    Total_logins            TS51            TS50      ...      Months_Worked  \
# 0             0  13-02-19 11:09  13-02-19 11:04      ...              23.37
# 1             1   14-10-19 8:26   14-10-19 8:26      ...              15.39
# 2             1  13-02-19 11:06  13-02-19 11:00      ...              13.55
# 3             4  13-02-19 11:06  13-02-19 11:00      ...              13.55
# 4             2  13-02-19 11:06  13-02-19 11:00      ...              13.52
#
#   Months_Worked_Roundoff                                     Mobile_OS_used  \
# ...

# %%
hr['Completion_Rate_Form'].value_counts()
# Out:
# 0      9275
# 100    5691
# Name: Completion_Rate_Form, dtype: int64

# %%
hr1 = hr[~(hr['Age'] >= 56)] 
hr1 = hr1[~(hr1['Age'] <= 17)]
hr1 = hr1[~(hr1['App_Logins'] > 40)]
hr1 = hr1[~(hr1['Web_Logins'] > 25)]
hr1 = hr1[~(hr1['Months_Worked_Roundoff']>20)]

# %%
hr1.head()
# Out:
#     Age  Gender2 Gender  Department Band  App_Logins  Web_Logins  \
# 1   NaN      NaN    NaN  Healthcare   A2           1           0
# 2   NaN      NaN    NaN   Insurance  NaN           1           0
# 3  35.0      0.0   Male     Finance  NaN           3           1
# 4   NaN      NaN    NaN     Finance  NaN           0           2
# 5  26.0      0.0   Male   Insurance  NaN           2           3
#
#    Total_logins            TS51            TS50      ...      Months_Worked  \
# 1             1   14-10-19 8:26   14-10-19 8:26      ...              15.39
# 2             1  13-02-19 11:06  13-02-19 11:00      ...              13.55
# 3             4  13-02-19 11:06  13-02-19 11:00      ...              13.55
# 4             2  13-02-19 11:06  13-02-19 11:00      ...              13.52
# 5             5  13-02-19 11:06  13-02-19 11:00      ...              13.52
#
#   Months_Worked_Roundoff                                     Mobile_OS_used  \
# ...

# %%
hrform=hr1.dropna(subset=['Form_Completed'],axis=0)
hrform=hrform.reset_index(drop=True)
hrform
# Out:
#        Age  Gender2  Gender  Department Band  App_Logins  Web_Logins  \
# 0     35.0      0.0    Male     Finance  NaN           3           1
# 1     26.0      0.0    Male   Insurance  NaN           2           3
# 2     37.0      0.0    Male     Finance  NaN           2           2
# 3     27.0      1.0  Female   Insurance  NaN           1           0
# 4     24.0      0.0    Male   Insurance  NaN           1           3
# 5     23.0      0.0    Male   Utilities  NaN           1           0
# 6     34.0      1.0  Female   Insurance  NaN           5           7
# 7     25.0      1.0  Female  Healthcare  NaN           1           3
# 8     31.0      0.0    Male   Insurance  NaN           3           0
# 9     25.0      0.0    Male   Insurance  NaN           1           3
# 10    34.0      1.0  Female     Finance  NaN           1           1
# 11    32.0      0.0    Male     Finance  NaN           2           1
# 12    29.0      0.0    Male   Utilities  NaN           2           0
# ...

# %%
f = lambda x: x['Form_Completed'].split()[1] 
hrform['Form_Completed1'] = hrform.apply(f,axis=1)
hrform
# Out:
#        Age  Gender2  Gender  Department Band  App_Logins  Web_Logins  \
# 0     35.0      0.0    Male     Finance  NaN           3           1
# 1     26.0      0.0    Male   Insurance  NaN           2           3
# 2     37.0      0.0    Male     Finance  NaN           2           2
# 3     27.0      1.0  Female   Insurance  NaN           1           0
# 4     24.0      0.0    Male   Insurance  NaN           1           3
# 5     23.0      0.0    Male   Utilities  NaN           1           0
# 6     34.0      1.0  Female   Insurance  NaN           5           7
# 7     25.0      1.0  Female  Healthcare  NaN           1           3
# 8     31.0      0.0    Male   Insurance  NaN           3           0
# 9     25.0      0.0    Male   Insurance  NaN           1           3
# 10    34.0      1.0  Female     Finance  NaN           1           1
# 11    32.0      0.0    Male     Finance  NaN           2           1
# 12    29.0      0.0    Male   Utilities  NaN           2           0
# ...

# %%
hr1['Whether_logged_in'].value_counts()
# Out:
#  0.0    6641
# -1.0    4058
#  1.0    1712
#  2.0    1227
#  3.0     615
#  4.0     323
# Name: Whether_logged_in, dtype: int64

# %%
plt.rcParams['figure.figsize']=(5,10)
sns.barplot(x=hr1['First_login_After_which_reminder'],y=hr1['App_Logins'], color = 'blue')
plt.title('Gender VS App_Logins', fontsize = 30)
plt.xlabel('App_Logins', fontsize = 15)
plt.ylabel('Gender', fontsize = 15)
plt.show()

# %%
hrlog=hr1.dropna(subset=['Whether_logged_in'])

# %%
plt.rcParams['figure.figsize'] = (15, 7)
sns.distplot(hrlog['Whether_logged_in'], color = 'blue')
plt.title('Distribution of Loggin after which reminder among the Employees', fontsize = 24)
plt.xlabel('logged in after which reminder', fontsize = 15)
plt.ylabel('count')
plt.show()

# %%
df_Gen = pd.DataFrame(columns=["Logged_after_which_reminder", "% of People"])
i=-1
for field in list(hr1['Whether_logged_in'].unique()):
    ratio= hr1[hr1['Whether_logged_in'] == field].shape[0]/ hr1.shape[0]
    df_Gen.loc[i] = (field, ratio*100)
    i += 1
    

df_Gen.plot(kind='bar',title='Logged_after_which_reminder (%)')

# %%
sns.axes_style('whitegrid')
sns.catplot('Whether_logged_in', data=hr1, aspect=3, kind='count', hue='Gender', palette=['Red', 'C0']).set_ylabels('Number of Employees')

# %%
hr_male= hr1[~(hr1['Gender'] == 'Female')]
hr_female= hr1[~(hr1['Gender'] == 'Male')]

# %%
hr1[hr1['Whether_logged_in'] == -1]
# Out:
#         Age  Gender2  Gender  Department Band  App_Logins  Web_Logins  \
# 6       NaN      NaN     NaN   Utilities  NaN           0           0
# 9       NaN      NaN     NaN   Utilities  NaN           0           0
# 10      NaN      NaN     NaN   Utilities  NaN           0           0
# 11      NaN      NaN     NaN   Insurance  NaN           0           0
# 13      NaN      NaN     NaN   Utilities  NaN           0           0
# 14      NaN      NaN     NaN   Utilities  NaN           0           0
# 15      NaN      NaN     NaN   Utilities  NaN           0           0
# 17      NaN      NaN     NaN   Insurance  NaN           0           0
# 26      NaN      NaN     NaN   Insurance  NaN           0           0
# 27      NaN      NaN     NaN   Utilities  NaN           0           0
# 31      NaN      NaN     NaN   Utilities  NaN           0           0
# 35      NaN      NaN     NaN   Utilities  NaN           0           0
# ...

# %%
hr5=hr1.dropna(subset=['Gender'])

# %%
hr5['Gender']=hr5['Gender'].astype('category')
hr5['Gender']=hr5['Gender'].cat.reorder_categories(['Female','Male'])
hr5['Gender']=hr5['Gender'].cat.codes
# Out:
# C:\Users\PARTH GUPTA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\PARTH GUPTA\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\PARTH GUPTA\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
hr1.shape[0]
# Out:
# 14748

# %%
hr1[hr1['Whether_logged_in'] == 0].shape
# Out:
# (6641, 74)

# %%
hr1.groupby('Gender').mean()
# Out:
#               Age   Gender2  App_Logins  Web_Logins  Total_logins  \
# Gender
# Female  25.752089  0.701381    8.392758    2.407614     10.800371
# Male    26.556007  0.139567    9.187218    2.694219     11.881436
#
#         Completion_Rate_Content  Completion_Rate_Form  Days_Worked  \
# Gender
# Female                31.934536             84.633240   147.913649
# Male                  34.161265             83.468835   147.554878
#
#         Months_Worked  Months_Worked_Roundoff  Whether_logged_in  \
# Gender
# Female       4.854721                4.836583           0.378709
# Male         4.842708                4.817977           0.370183
#
#         Logged_or_not
# Gender
# Female      90.343853
# Male        91.376147

# %%
plt.figure(figsize=(15,6))
plt.style.use('seaborn-colorblind')
plt.grid(True, alpha=0.5)
sns.kdeplot(hr5.loc[hr5['Gender'] == 0, 'Whether_logged_in'], label = 'Female',color='Red')
sns.kdeplot(hr5.loc[hr5['Gender'] == 1,'Whether_logged_in'], label = 'Male')
plt.xlabel('Whether_logged_in')
plt.xlim(left=-2)
plt.ylabel('Density')
plt.title('Logged in after which attempt by Gender');
# Out:
# C:\Users\PARTH GUPTA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\PARTH GUPTA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\PARTH GUPTA\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
hr5.head()
# Out:
#      Age  Gender2  Gender Department Band  App_Logins  Web_Logins  \
# 3   35.0      0.0       1    Finance  NaN           3           1
# 5   26.0      0.0       1  Insurance  NaN           2           3
# 8   37.0      0.0       1    Finance  NaN           2           2
# 18  27.0      1.0       0  Insurance  NaN           1           0
# 20  24.0      0.0       1  Insurance  NaN           1           3
#
#     Total_logins            TS51            TS50      ...      Months_Worked  \
# 3              4  13-02-19 11:06  13-02-19 11:00      ...              13.55
# 5              5  13-02-19 11:06  13-02-19 11:00      ...              13.52
# 8              4  07-05-19 22:25  13-02-19 11:06      ...              13.52
# 18             1  31-08-19 19:20  13-02-19 11:06      ...              13.46
# 20             4  13-02-19 11:06  13-02-19 11:00      ...              13.46
#
#    Months_Worked_Roundoff                                     Mobile_OS_used  \
# ...

# %%
hrband=hr1.dropna(subset=['Band'])

# %%
hrband['Logged_or_not'].value_counts()
# Out:
# 100.0    10249
# 0.0       3885
# Name: Logged_or_not, dtype: int64

# %%
hr1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14748 entries, 1 to 14965
# Data columns (total 74 columns):
# Age                                 6582 non-null float64
# Gender2                             6531 non-null float64
# Gender                              6582 non-null object
# Department                          14748 non-null object
# Band                                14306 non-null object
# App_Logins                          14748 non-null int64
# Web_Logins                          14748 non-null int64
# Total_logins                        14748 non-null int64
# TS51                                14748 non-null object
# TS50                                14748 non-null object
# TS49                                14748 non-null object
# TS48                                14748 non-null object
# TS47                                14748 non-null object
# TS46                                14748 non-null object
# ...

# %%
plt.rcParams['figure.figsize']=(25,12)
sns.barplot(y=hr1['Whether_logged_in'],x=hr1['Months_Worked_Roundoff'], color = 'C1')
plt.title('No. of reminders Vs Months_Worked', fontsize = 30)
plt.ylabel('No. of reminders', fontsize = 15)
plt.xlabel('Months_Worked_Roundoff', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize']=(25,12)
sns.barplot(y=hr1['Whether_logged_in'],x=hr1['Age'], color = 'C1')
plt.title('No. of reminders Vs Age', fontsize = 30)
plt.ylabel('No. of reminders', fontsize = 15)
plt.xlabel('Age', fontsize = 15)
plt.show()

# %%
hr1['Whether_logged_in'].value_counts()
# Out:
#  0.0    6641
# -1.0    4058
#  1.0    1712
#  2.0    1227
#  3.0     615
#  4.0     323
# Name: Whether_logged_in, dtype: int64

# %%
hr00=hr1[hr1['Whether_logged_in']==0]
hr01=hr1[hr1['Whether_logged_in']==1]
hr02=hr1[hr1['Whether_logged_in']==2]
hr03=hr1[hr1['Whether_logged_in']==3]
hr04=hr1[hr1['Whether_logged_in']==4]
hr99=hr1[hr1['Whether_logged_in']==-1]

# %%
hr1['Gender'].value_counts()
# Out:
# Male      4428
# Female    2154
# Name: Gender, dtype: int64

# %%
plt.rcParams['figure.figsize']=(8,7)
sns.barplot(y=hr1['Whether_logged_in'],x=hr1['Gender'], color = 'C1')
plt.title('No. of reminders Vs Gender', fontsize = 30)
plt.ylabel('No. of reminders', fontsize = 15)
plt.xlabel('Gender', fontsize = 15)
plt.show()

# %%
hrrem = hr1[~(hr1['Whether_logged_in'] < 1)]
hrrem['Whether_logged_in'].value_counts()
# Out:
# 1.0    1712
# 2.0    1227
# 3.0     615
# 4.0     323
# Name: Whether_logged_in, dtype: int64

# %%
plt.rcParams['figure.figsize']=(8,7)
sns.barplot(y=hrrem['Whether_logged_in'],x=hrrem['Gender'], color = 'C1')
plt.title('No. of reminders Vs Gender', fontsize = 30)
plt.ylabel('No. of reminders', fontsize = 15)
plt.xlabel('Gender', fontsize = 15)
plt.show()

# %%
hr00Gender=hr00.dropna(subset=['Gender2'])
hr01Gender=hr01.dropna(subset=['Gender2'])
hr02Gender=hr02.dropna(subset=['Gender2'])
hr03Gender=hr03.dropna(subset=['Gender2'])
hr04Gender=hr04.dropna(subset=['Gender2'])
hr99Gender=hr99.dropna(subset=['Gender2'])

# %%
import matplotlib.ticker as mtick

# %%
table= pd.crosstab(hr1.Whether_logged_in,hr.Gender)
table.div(table.sum(1),axis=0).plot(kind='bar',stacked=False)

# %%
plt.rcParams['figure.figsize'] = (15, 7)
sns.distplot(hr00Gender['Gender2'], color = 'blue', norm_hist=True, kde=False)
plt.title('Distribution of Gender who logs in in the first attempt', fontsize = 24)
plt.xlabel('0=Female and 1=Male', fontsize = 15)
plt.ylabel('count')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 7)
sns.distplot(hr01Gender['Gender2'], color = 'blue')
plt.title('Distribution of Gender who logs in after 1st reminder', fontsize = 24)
plt.xlabel('0=Female and 1=Male', fontsize = 15)
plt.ylabel('count')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 7)
sns.distplot(hr02Gender['Gender2'], color = 'blue')
plt.title('Distribution of Gender who logs in after 2nd reminder', fontsize = 24)
plt.xlabel('0=Female and 1=Male', fontsize = 15)
plt.ylabel('count')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 7)
sns.distplot(hr03Gender['Gender2'], color = 'blue')
plt.title('Distribution of Gender who logs in after 3rd reminder', fontsize = 24)
plt.xlabel('0=Female and 1=Male', fontsize = 15)
plt.ylabel('count')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 7)
sns.distplot(hr04Gender['Gender2'], color = 'blue')
plt.title('Distribution of Gender who logs in after 4th reminder', fontsize = 24)
plt.xlabel('0=Female and 1=Male', fontsize = 15)
plt.ylabel('count')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 7)
sns.distplot(hr99Gender['Gender2'], color = 'blue')
plt.title('Distribution of Gender who did not login', fontsize = 24)
plt.xlabel('0=Female and 1=Male', fontsize = 15)
plt.ylabel('count')
plt.show()

# %%
hrrem = hr1[~(hr1['Whether_logged_in'] < 0)]
hrrem['Whether_logged_in'].value_counts()
# Out:
# 0.0    6641
# 1.0    1712
# 2.0    1227
# 3.0     615
# 4.0     323
# Name: Whether_logged_in, dtype: int64

# %%
plt.rcParams['figure.figsize']=(18,12)
sns.barplot(x=hrrem['Whether_logged_in'],y=hrrem['App_Logins'], color = 'C1')
sns.regplot(x=hrrem['Whether_logged_in'],y=hrrem['App_Logins'], x_estimator=np.mean, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=None, n_boot=1000, units=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=False, dropna=True, x_jitter=None, y_jitter=None, label='Red', color='red', marker='o', scatter_kws=None, line_kws=None, ax=None)
plt.title('No. of reminders Vs App_Logins', fontsize = 30)
plt.ylabel('No. of reminders', fontsize = 15)
plt.xlabel('No. of App_Logins', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize']=(18,12)
sns.barplot(x=hrrem['Whether_logged_in'],y=hrrem['Web_Logins'], color = 'C1')
sns.regplot(x=hrrem['Whether_logged_in'],y=hrrem['Web_Logins'], x_estimator=np.mean, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=None, n_boot=1000, units=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=False, dropna=True, x_jitter=None, y_jitter=None, label='Red', color='red', marker='o', scatter_kws=None, line_kws=None, ax=None)
plt.title('No. of reminders Vs Web_Logins', fontsize = 30)
plt.ylabel('No. of reminders', fontsize = 15)
plt.xlabel('No. of Web_Logins', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize']=(8,7)
sns.barplot(y=hrrem['Whether_logged_in'],x=hrrem['Band'], color = 'C1')
plt.title('No. of reminders Vs Band', fontsize = 30)
plt.ylabel('No. of reminders', fontsize = 15)
plt.xlabel('Band', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize']=(8,7)
sns.barplot(y=hrrem['Whether_logged_in'],x=hrrem['Department'], color = 'C1')
plt.title('No. of reminders Vs Department', fontsize = 30)
plt.ylabel('No. of reminders', fontsize = 15)
plt.xlabel('Department', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize']=(8,7)
sns.barplot(y=hrrem['Completion_Rate_Content'],x=hrrem['Whether_logged_in'], color = 'C3')
plt.title('No. of reminders Vs Completion Rate', fontsize = 30)
plt.ylabel('Completion Rate', fontsize = 15)
plt.xlabel('No. of reminders', fontsize = 15)
plt.show()

# %%
hrtime=hr1.dropna(subset=['Form_Sent'],axis=0)
hrtime=hrtime.dropna(subset=['Form_Completed'],axis=0)

# %%
from collections import Counter
data = pd.read_csv('P:/TYDY/Behavioral_Alisha.csv')

data["TS40"]= data["TS40"].astype(str)
data["TS41"]= data["TS41"].astype(str)
#datetimeFormat = '%Y-%m-%d %H:%M.%f'
datetimeFormat = '%d-%m-%y %H:%M'
arr = []
for i in range(2, 14000):
    date1 = data['TS40'][i]
    date2 = data['TS41'][i]
    diff = datetime.datetime.strptime(date1, datetimeFormat)-datetime.datetime.strptime(date2, datetimeFormat)
    Days_between = diff.days
    #arr[i] = Days_between
    print(i , Days_between)
# Out:
# 2 -1
# 3 -1
# 4 -2
# 5 -1
# 6 -1
# 7 -1
# 8 -1
# 9 0
# 10 -1
# 11 -1
# 12 -1
# 13 -1
# 14 0
# 15 -1
# 16 389
# 17 0
# 18 -1
# 19 0
# 20 254
# 21 154
# 22 161
# 23 0
# 24 -1
# 25 0
# 26 1
# 27 0
# 28 -1
# 29 280
# 30 280
# 31 0
# 32 227
# 33 -1
# 34 0
# 35 0
# 36 335
# 37 -1
# 38 0
# 39 236
# 40 -1
# 41 298
# 42 -2
# 43 0
# 44 -1
# 45 -1
# 46 20
# 47 0
# 48 -1
# 49 223
# 50 287
# 51 236
# 52 112
# 53 -5
# 54 0
# 55 0
# 56 0
# 57 0
# 58 266
# 59 0
# 60 228
# 61 0
# 62 0
# 63 0
# 64 258
# 65 189
# 66 -1
# 67 222
# 68 -1
# 69 -1
# 70 0
# 71 -1
# 72 0
# 73 293
# 74 0
# 75 0
# 76 -1
# 77 -1
# 78 -1
# 79 0
# 80 -1
# 81 -3
# 82 -1
# 83 0
# 84 0
# 85 -1
# 86 -1
# 87 0
# 88 0
# 89 0
# 90 0
# 91 0
# 92 -1
# 93 0
# 94 0
# 95 0
# 96 228
# 97 0
# 98 0
# 99 0
# 100 0
# 101 0
# 102 0
# 103 -1
# 104 197
# 105 -1
# 106 0
# 107 0
# 108 -1
# 109 0
# 110 0
# 111 0
# 112 0
# 113 0
# 114 -1
# 115 0
# 116 -1
# 117 -1
# 118 1
# 119 0
# 120 -1
# 121 0
# 122 0
# 123 -1
# 124 0
# 125 -1
# 126 -1
# 127 -1
# ...

# %%
hrtime=hrtime.reset_index(drop=True)
hrtime

# %%
from collections import Counter
data = pd.read_csv('P:/TYDY/Behavioral_Alisha.csv')

hrtime['Form_Sent']= hrtime['Form_Sent'].astype(str)
hrtime['Form_Completed']= hrtime['Form_Completed'].astype(str)
#datetimeFormat = '%Y-%m-%d %H:%M.%f'
datetimeFormat = '%d-%m-%y %H:%M'
arr = []
for i in range(0, 5519):
    date2 = hrtime['Form_Sent'][i]
    date1 = hrtime['Form_Completed'][i]
    diff = datetime.datetime.strptime(date1, datetimeFormat)-datetime.datetime.strptime(date2, datetimeFormat)
    Days_between = diff.days
    Minutes_between = (diff.seconds)/60
    arr.append(i)
    arr[i] = Days_between*24*60 + Minutes_between

arr=np.array(arr)

# %%
hrtime['Minutes'] = pd.Series(np.random.randn(5519), index=hrtime.index)

# %%
for i in range(0,5519):
    hrtime['Minutes'][i] = arr[i]
# Out:
# C:\Users\PARTH GUPTA\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
hrtime
# Out:
#        Age  Gender2  Gender  Department Band  App_Logins  Web_Logins  \
# 0     35.0      0.0    Male     Finance  NaN           3           1
# 1     26.0      0.0    Male   Insurance  NaN           2           3
# 2     37.0      0.0    Male     Finance  NaN           2           2
# 3     27.0      1.0  Female   Insurance  NaN           1           0
# 4     24.0      0.0    Male   Insurance  NaN           1           3
# 5     23.0      0.0    Male   Utilities  NaN           1           0
# 6     34.0      1.0  Female   Insurance  NaN           5           7
# 7     25.0      1.0  Female  Healthcare  NaN           1           3
# 8     31.0      0.0    Male   Insurance  NaN           3           0
# 9     25.0      0.0    Male   Insurance  NaN           1           3
# 10    34.0      1.0  Female     Finance  NaN           1           1
# 11    32.0      0.0    Male     Finance  NaN           2           1
# 12    29.0      0.0    Male   Utilities  NaN           2           0
# ...

# %%
hr_browser=hr1[~hr1.Browser_used.str.contains("UnKnown-UnKnown")]
hr_browser=hr_browser[~hr_browser.Browser_used.str.contains("Internet")]
hr_browser=hr_browser.reset_index(drop=True)
hr_browser.head()
# Out:
#     Age  Gender2  Gender Department Band  App_Logins  Web_Logins  \
# 0  37.0      0.0    Male    Finance  NaN           2           2
# 1  27.0      1.0  Female  Insurance  NaN           1           0
# 2   NaN      NaN     NaN  Insurance  NaN           3           0
# 3  28.0      0.0    Male  Insurance  NaN           1           0
# 4  31.0      0.0    Male  Insurance  NaN           3           0
#
#    Total_logins            TS51            TS50      ...      Months_Worked  \
# 0             4  07-05-19 22:25  13-02-19 11:06      ...              13.52
# 1             1  31-08-19 19:20  13-02-19 11:06      ...              13.46
# 2             3  02-09-19 13:17  13-02-19 11:06      ...              13.46
# 3             1  31-08-19 19:22  13-02-19 11:06      ...              13.46
# 4             3  31-08-19 19:22  13-02-19 11:06      ...              13.46
#
#   Months_Worked_Roundoff                                     Mobile_OS_used  \
# ...

# %%
f = lambda x: x['Browser_used'].split()[0] 
hr_browser['Browser_used'] = hr_browser.apply(f,axis=1)
g = lambda x: x['Browser_used'].split('-')[0] 
hr_browser['Browser_used'] = hr_browser.apply(g,axis=1)

# %%
hr_browser['Browser_used'].value_counts()
# Out:
# Google     6329
# Apple       189
# Firefox     142
# Name: Browser_used, dtype: int64

# %%
hr_browser.groupby('Browser_used').mean()
# Out:
#                     Age   Gender2  App_Logins  Web_Logins  Total_logins  \
# Browser_used
# Apple         26.162791  0.392405    6.328042    2.423280      8.751323
# Firefox       26.382979  0.298851    4.478873    4.725352      9.204225
# Google        26.084784  0.316197    7.835835    2.126876      9.962711
#
#               Completion_Rate_Content  Completion_Rate_Form  Days_Worked  \
# Browser_used
# Apple                       33.766296             40.211640   130.619048
# Firefox                     30.008169             57.042254   159.415493
# Google                      30.282143             59.314268   140.142361
#
#               Months_Worked  Months_Worked_Roundoff  Whether_logged_in  \
# Browser_used
# Apple              4.286984                4.285714           0.397849
# Firefox            5.231549                5.288732           0.390071
# Google             4.599499                4.577342           0.379305
#
#               Logged_or_not
# Browser_used
# ...

# %%
plt.rcParams['figure.figsize']=(8,7)
sns.barplot(x=hr_browser['Browser_used'],y=hr_browser['App_Logins'], color = 'C3', alpha=0.4)
sns.barplot(x=hr_browser['Browser_used'],y=hr_browser['Web_Logins'], color = 'C2', alpha=0.4)
plt.title('No. of reminders Vs Completion Rate', fontsize = 30)
plt.ylabel('No. of logins', fontsize = 15)
plt.xlabel('Browser_used', fontsize = 15)
plt.show()

# %%
hr1['Age'].value_counts()
# Out:
# 23.0    754
# 24.0    735
# 25.0    694
# 26.0    635
# 22.0    629
# 27.0    527
# 28.0    425
# 21.0    399
# 29.0    341
# 30.0    272
# 31.0    223
# 32.0    164
# 33.0    138
# 20.0    124
# 34.0    102
# 35.0     94
# 37.0     62
# 36.0     57
# 38.0     44
# 19.0     32
# 40.0     30
# 41.0     21
# 39.0     21
# 43.0     15
# 42.0     10
# 18.0     10
# 44.0      9
# 45.0      4
# 47.0      3
# 46.0      3
# 54.0      2
# 50.0      1
# 51.0      1
# 55.0      1
# Name: Age, dtype: int64

# %%
hr_age=hr1.dropna(subset=['Age'],axis=0)
hr_age=hr_age.reset_index(drop=True)
hr_age
# Out:
#        Age  Gender2  Gender  Department Band  App_Logins  Web_Logins  \
# 0     35.0      0.0    Male     Finance  NaN           3           1
# 1     26.0      0.0    Male   Insurance  NaN           2           3
# 2     37.0      0.0    Male     Finance  NaN           2           2
# 3     27.0      1.0  Female   Insurance  NaN           1           0
# 4     24.0      0.0    Male   Insurance  NaN           1           3
# 5     23.0      0.0    Male   Utilities  NaN           1           0
# 6     34.0      1.0  Female   Insurance  NaN           5           7
# 7     25.0      1.0  Female  Healthcare  NaN           1           3
# 8     28.0      0.0    Male   Insurance  NaN           1           0
# 9     31.0      0.0    Male   Insurance  NaN           3           0
# 10    25.0      0.0    Male   Insurance  NaN           1           3
# 11    34.0      1.0  Female     Finance  NaN           1           1
# 12    28.0      1.0  Female  Healthcare  NaN           1           0
# ...

# %%
for i in range(0, 6581):
    if (hr_age['Age'][i] > 18 and hr_age['Age'][i] < 26):
        hr_age['Age'][i] = 18
    elif (hr_age['Age'][i] > 25 and hr_age['Age'][i] < 31):
        hr_age['Age'][i] = 26
    elif (hr_age['Age'][i] > 30 and hr_age['Age'][i] < 36):
        hr_age['Age'][i] = 31
    elif (hr_age['Age'][i] > 35 and hr_age['Age'][i] < 41):
        hr_age['Age'][i] = 36
    elif (hr_age['Age'][i] > 40 and hr_age['Age'][i] < 46):
        hr_age['Age'][i] = 41
    elif (hr_age['Age'][i] > 45 and hr_age['Age'][i] < 51):
        hr_age['Age'][i] = 46
    else :
        hr_age['Age'][i] = 51
# Out:
# C:\Users\PARTH GUPTA\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\PARTH GUPTA\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\PARTH GUPTA\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# ...

# %%
hr_age
# Out:
#        Age  Gender2  Gender  Department Band  App_Logins  Web_Logins  \
# 0     31.0      0.0    Male     Finance  NaN           3           1
# 1     26.0      0.0    Male   Insurance  NaN           2           3
# 2     36.0      0.0    Male     Finance  NaN           2           2
# 3     26.0      1.0  Female   Insurance  NaN           1           0
# 4     18.0      0.0    Male   Insurance  NaN           1           3
# 5     18.0      0.0    Male   Utilities  NaN           1           0
# 6     31.0      1.0  Female   Insurance  NaN           5           7
# 7     18.0      1.0  Female  Healthcare  NaN           1           3
# 8     26.0      0.0    Male   Insurance  NaN           1           0
# 9     31.0      0.0    Male   Insurance  NaN           3           0
# 10    18.0      0.0    Male   Insurance  NaN           1           3
# 11    31.0      1.0  Female     Finance  NaN           1           1
# 12    26.0      1.0  Female  Healthcare  NaN           1           0
# ...

# %%
hr1
# Out:
#         Age  Gender2  Gender  Department Band  App_Logins  Web_Logins  \
# 1       NaN      NaN     NaN  Healthcare   A2           1           0
# 2       NaN      NaN     NaN   Insurance  NaN           1           0
# 3      35.0      0.0    Male     Finance  NaN           3           1
# 4       NaN      NaN     NaN     Finance  NaN           0           2
# 5      26.0      0.0    Male   Insurance  NaN           2           3
# 6       NaN      NaN     NaN   Utilities  NaN           0           0
# 7       NaN      NaN     NaN     Finance  NaN           0           1
# 8      37.0      0.0    Male     Finance  NaN           2           2
# 9       NaN      NaN     NaN   Utilities  NaN           0           0
# 10      NaN      NaN     NaN   Utilities  NaN           0           0
# 11      NaN      NaN     NaN   Insurance  NaN           0           0
# 12      NaN      NaN     NaN   Insurance  NaN           4           0
# ...

# %%
hr1_not_logged = hr1[hr1['Logged_or_not'] == 0]
hr1_not_logged=hr1_not_logged.reset_index(drop=True)

# %%
hr1_not_logged
# Out:
#        Age  Gender2  Gender  Department Band  App_Logins  Web_Logins  \
# 0      NaN      NaN     NaN   Utilities  NaN           0           0
# 1      NaN      NaN     NaN   Utilities  NaN           0           0
# 2      NaN      NaN     NaN   Utilities  NaN           0           0
# 3      NaN      NaN     NaN   Insurance  NaN           0           0
# 4      NaN      NaN     NaN   Utilities  NaN           0           0
# 5      NaN      NaN     NaN   Utilities  NaN           0           0
# 6      NaN      NaN     NaN   Utilities  NaN           0           0
# 7      NaN      NaN     NaN   Insurance  NaN           0           0
# 8      NaN      NaN     NaN   Insurance  NaN           0           0
# 9      NaN      NaN     NaN   Utilities  NaN           0           0
# 10     NaN      NaN     NaN   Utilities  NaN           0           0
# 11     NaN      NaN     NaN   Utilities  NaN           0           0
# 12     NaN      NaN     NaN   Utilities  NaN           0           0
# ...

# %%
hr1_not_logged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4058 entries, 0 to 4057
# Data columns (total 74 columns):
# Age                                 581 non-null float64
# Gender2                             37 non-null float64
# Gender                              581 non-null object
# Department                          4058 non-null object
# Band                                3885 non-null object
# App_Logins                          4058 non-null int64
# Web_Logins                          4058 non-null int64
# Total_logins                        4058 non-null int64
# TS51                                4058 non-null object
# TS50                                4058 non-null object
# TS49                                4058 non-null object
# TS48                                4058 non-null object
# TS47                                4058 non-null object
# TS46                                4058 non-null object
# TS45                                4058 non-null object
# ...

# %%
hr_female
# Out:
#         Age  Gender2  Gender  Department Band  App_Logins  Web_Logins  \
# 1       NaN      NaN     NaN  Healthcare   A2           1           0
# 2       NaN      NaN     NaN   Insurance  NaN           1           0
# 4       NaN      NaN     NaN     Finance  NaN           0           2
# 6       NaN      NaN     NaN   Utilities  NaN           0           0
# 7       NaN      NaN     NaN     Finance  NaN           0           1
# 9       NaN      NaN     NaN   Utilities  NaN           0           0
# 10      NaN      NaN     NaN   Utilities  NaN           0           0
# 11      NaN      NaN     NaN   Insurance  NaN           0           0
# 12      NaN      NaN     NaN   Insurance  NaN           4           0
# 13      NaN      NaN     NaN   Utilities  NaN           0           0
# 14      NaN      NaN     NaN   Utilities  NaN           0           0
# 15      NaN      NaN     NaN   Utilities  NaN           0           0
# ...

# %%
plt.figure(figsize=(15,6))
plt.style.use('seaborn-colorblind')
plt.grid(True, alpha=0.5)
sns.kdeplot(hr1.loc[hr1['Gender'] == 'Male', 'App_Logins'], label = 'Males')
sns.kdeplot(hr1.loc[hr1['Gender'] == 'Female', 'App_Logins'], label = 'Females')
plt.xlabel('Number of App Logins')
plt.xlim(left=0)
plt.ylabel('Density')
plt.title('Gender by App Login Status');
# Out:
# C:\Users\PARTH GUPTA\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.axes_style('whitegrid')
sns.catplot('App_Logins', data=hr1, aspect=3, kind='count', hue='Gender', palette=['C3', 'C0']).set_ylabels('Number of Employees')
