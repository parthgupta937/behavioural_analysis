# %%
import pandas as pd
import numpy as np
hr = pd.read_csv('C:/Users/Dell/Desktop/Tydy/Main_data_DepSorted.csv')

# %%
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import matplotlib
# %matplotlib inline

# %%
hr.head()
# Out:
#    Age Gender Department Band  Work_Experience Previous_Employer School   Pu  \
# 0  NaN    NaN    Finance   A2              NaN               NaN    NaN  NaN
# 1  NaN    NaN         HR   A1              NaN               NaN    NaN  NaN
# 2  NaN    NaN    Travels  NaN              NaN               NaN    NaN  NaN
# 3  NaN    NaN    Travels  NaN              NaN               NaN    NaN  NaN
# 4  NaN    NaN    Travels  NaN              NaN               NaN    NaN  NaN
#
#   Graduate Post_Graduation    ...    Completion_Rate_Form  start_date  \
# 0      NaN             NaN    ...                       1  11/15/2018
# 1      NaN             NaN    ...                       1    12-04-18
# 2      NaN             NaN    ...                       0    11-12-18
# 3      NaN             NaN    ...                       0    11-12-18
# 4      NaN             NaN    ...                       0  11/14/2018
#
#    end_date Days_worked Number_of_Months_Exact  Number_of_ Months_RoundUp  \
# 0  12-09-19         389                  12.79                         13
# 1  12-09-19         370                  12.16                         12
# 2  12-09-19         392                  12.89                         13
# 3  12-09-19         392                  12.89                         13
# 4  12-09-19         390                  12.82                         13
#
#    City_Permanent_Address  PAN_Card Aadhaar  Passport
# 0                     NaN       NaN     NaN       NaN
# 1                     NaN       NaN     NaN       NaN
# 2                     NaN       NaN     NaN       NaN
# 3                     NaN       NaN     NaN       NaN
# 4                     NaN       NaN     NaN       NaN
#
# [5 rows x 22 columns]

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14757 entries, 0 to 14756
# Data columns (total 22 columns):
# Age                          14731 non-null float64
# Gender                       6675 non-null object
# Department                   14757 non-null object
# Band                         14304 non-null object
# Work_Experience              2806 non-null float64
# Previous_Employer            3974 non-null object
# School                       6366 non-null object
# Pu                           6394 non-null object
# Graduate                     6233 non-null object
# Post_Graduation              1765 non-null object
# Marital_Status               6675 non-null object
# Completion_Rate_Content      14757 non-null float64
# Completion_Rate_Form         14757 non-null int64
# start_date                   14757 non-null object
# end_date                     14757 non-null object
# Days_worked                  14757 non-null int64
# Number_of_Months_Exact       14757 non-null float64
# Number_of_ Months_RoundUp    14757 non-null int64
# City_Permanent_Address       6674 non-null object
# PAN_Card                     6675 non-null float64
# Aadhaar                      6675 non-null float64
# Passport                     6630 non-null float64
# dtypes: float64(7), int64(3), object(12)
# memory usage: 2.5+ MB

# %%
hr=hr.drop(['start_date'],axis=1)

# %%
hr=hr.drop(['end_date'],axis=1)

# %%
hr=hr.drop(['Number_of_Months_Exact'],axis=1)

# %%
hr1=hr.drop(['Days_worked'],axis=1)
hr1=hr1.drop(['Completion_Rate_Content'],axis=1)
hr1 = hr1[hr1['Age'] <=56 ]
hr1 = hr1[hr1['Age'] >=18 ]
hr1 = hr1[hr1['Number_of_ Months_RoundUp'] <=25]

# %%
hr2=hr.drop(['Number_of_ Months_RoundUp'],axis=1)

# %%
hr1['Completion_Rate_Form'].value_counts()
# Out:
# 1    14214
# 0      335
# Name: Completion_Rate_Form, dtype: int64

# %%
hr1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14549 entries, 26 to 14756
# Data columns (total 17 columns):
# Age                          14549 non-null float64
# Gender                       6591 non-null object
# Department                   14549 non-null object
# Band                         14124 non-null object
# Work_Experience              2766 non-null float64
# Previous_Employer            3921 non-null object
# School                       6288 non-null object
# Pu                           6315 non-null object
# Graduate                     6153 non-null object
# Post_Graduation              1739 non-null object
# Marital_Status               6591 non-null object
# Completion_Rate_Form         14549 non-null int64
# Number_of_ Months_RoundUp    14549 non-null int64
# City_Permanent_Address       6590 non-null object
# PAN_Card                     6591 non-null float64
# Aadhaar                      6591 non-null float64
# Passport                     6548 non-null float64
# dtypes: float64(5), int64(2), object(10)
# memory usage: 2.0+ MB

# %%
hr10=hr1.dropna()

# %%
hr10['Completion_Rate_Form'].value_counts()
# Out:
# 1    808
# Name: Completion_Rate_Form, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.heatmap(hr1.corr(method='spearman'), cmap='coolwarm', annot=True)
plt.tight_layout()
plt.show()

# %%
hr1.describe(include='all')
# Out:
#                  Age Gender Department   Band  Work_Experience  \
# count   14549.000000   6591      14549  14124      2766.000000
# unique           NaN      2          9     11              NaN
# top              NaN   Male  Insurance     A1              NaN
# freq             NaN   4443       6087  10916              NaN
# mean       26.251907    NaN        NaN    NaN         3.689082
# std         4.433991    NaN        NaN    NaN         3.066273
# min        18.000000    NaN        NaN    NaN         0.000000
# 25%        23.000000    NaN        NaN    NaN         2.000000
# 50%        25.000000    NaN        NaN    NaN         3.000000
# 75%        28.000000    NaN        NaN    NaN         5.000000
# max        55.000000    NaN        NaN    NaN        20.000000
#
#        Previous_Employer  School    Pu                 Graduate  \
# count               3921    6288  6315                     6153
# unique              2915    5849  5775                     4963
# top              Genpact  School  NIOS  School of open learning
# freq                 106      23    29                      127
# mean                 NaN     NaN   NaN                      NaN
# std                  NaN     NaN   NaN                      NaN
# min                  NaN     NaN   NaN                      NaN
# 25%                  NaN     NaN   NaN                      NaN
# 50%                  NaN     NaN   NaN                      NaN
# 75%                  NaN     NaN   NaN                      NaN
# max                  NaN     NaN   NaN                      NaN
#
#        Post_Graduation Marital_Status  Completion_Rate_Form  \
# count             1739           6591          14549.000000
# unique            1449              5                   NaN
# top              IGNOU         Single                   NaN
# freq                42           5210                   NaN
# mean               NaN            NaN              0.976974
# std                NaN            NaN              0.149990
# min                NaN            NaN              0.000000
# 25%                NaN            NaN              1.000000
# 50%                NaN            NaN              1.000000
# 75%                NaN            NaN              1.000000
# max                NaN            NaN              1.000000
#
#         Number_of_ Months_RoundUp City_Permanent_Address     PAN_Card  \
# count                14549.000000                   6590  6591.000000
# unique                        NaN                   1830          NaN
# top                           NaN                  Delhi          NaN
# freq                          NaN                    559          NaN
# mean                     5.023644                    NaN     0.939008
# std                      3.370262                    NaN     0.239334
# min                     -7.000000                    NaN     0.000000
# 25%                      3.000000                    NaN     1.000000
# 50%                      5.000000                    NaN     1.000000
# 75%                      7.000000                    NaN     1.000000
# max                     23.000000                    NaN     1.000000
#
#             Aadhaar     Passport
# count   6591.000000  6548.000000
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# mean       0.994841     0.337966
# std        0.071643     0.473053
# min        0.000000     0.000000
# 25%        1.000000     0.000000
# 50%        1.000000     0.000000
# 75%        1.000000     1.000000
# max        1.000000     1.000000

# %%
hr['City_Permanent_Address'].value_counts()
# Out:
# Delhi                                                                 564
# New Delhi                                                             414
# Ghaziabad                                                             333
# Pune                                                                  212
# Noida                                                                 151
# Bengaluru                                                             145
# Jaipur                                                                116
# Bangalore                                                             108
# Meerut                                                                 90
# New delhi                                                              80
# Faridabad                                                              79
# DELHI                                                                  69
# delhi                                                                  64
# Lucknow                                                                58
# Kanpur                                                                 58
# NEW DELHI                                                              50
# Aligarh                                                                46
# Agra                                                                   44
# Ernakulam                                                              41
# GHAZIABAD                                                              36
# Muzaffarnagar                                                          35
# Bareilly                                                               35
# Greater Noida                                                          34
# Bulandshahr                                                            31
# new delhi                                                              30
# Patna                                                                  29
# Kolkata                                                                28
# Hapur                                                                  27
# Dehradun                                                               27
# Mathura                                                                26
#                                                                      ...
# Chittorgarh                                                             1
# UTTAM NAGAR                                                             1
# digboi                                                                  1
# Nandikotkur                                                             1
# Nallacheruvu                                                            1
# Manjeshwara                                                             1
# Jehanabad                                                               1
# NANGLOI                                                                 1
# Solan himachal Pradesh                                                  1
# Etah (up)                                                               1
# KOLHAPUR                                                                1
# Sonepur                                                                 1
# SAS Nagar                                                               1
# MEHATPUR UNA HP                                                         1
# Saharanpur,UP                                                           1
# UDUPI                                                                   1
# Tiruppur                                                                1
# ottapalam                                                               1
# NALANDA                                                                 1
# Dehra                                                                   1
# RANNY                                                                   1
# Shahdara, Delhi                                                         1
# Muzaffarnagar Uttar Pradesh                                             1
# Gundlupete                                                              1
# VADODARA                                                                1
# 297-Group 1 Hastsal Janta Flat, Uttam Nagar East, New Delhi 110059      1
# BOKARO STEEL CITY, jHARKHAND                                            1
# Tundla Distt- Firozabad                                                 1
# Bulandshahr,uttar pradesh                                               1
# Burari                                                                  1
# Name: City_Permanent_Address, Length: 1847, dtype: int64

# %%
hr1['Age'].value_counts()
# Out:
# 23.0    1689
# 24.0    1602
# 25.0    1453
# 26.0    1362
# 22.0    1288
# 21.0    1149
# 27.0    1116
# 28.0     999
# 29.0     790
# 30.0     546
# 31.0     444
# 32.0     371
# 33.0     333
# 20.0     236
# 34.0     212
# 35.0     200
# 36.0     184
# 37.0     159
# 38.0      88
# 19.0      70
# 39.0      53
# 41.0      48
# 40.0      48
# 43.0      38
# 44.0      19
# 18.0      17
# 42.0      15
# 46.0       6
# 45.0       5
# 47.0       4
# 54.0       2
# 51.0       1
# 55.0       1
# 50.0       1
# Name: Age, dtype: int64

# %%
hr['Department'].value_counts()
# Out:
# Insurance     6162
# Healthcare    2482
# Finance       2140
# Travels       1410
# Analytics     1094
# Utilities      713
# Sales          379
# HR             212
# Technology     165
# Name: Department, dtype: int64

# %%
hr['Completion_Rate_Form'].value_counts()
# Out:
# 1    14397
# 0      360
# Name: Completion_Rate_Form, dtype: int64

# %%
hr1['Band'].value_counts()
# Out:
# A1    10916
# A2     1494
# B1      928
# B2      333
# C1      262
# C2      109
# D1       41
# D2       21
# E1       17
# E2        2
# F         1
# Name: Band, dtype: int64

# %%
hr2=(hr['Band'])
hr3=hr['Completion_Rate_Form']

# %%
hr4=hr.dropna(subset=['Band'])
hr4.head()
# Out:
#       Age  Gender Department Band  Work_Experience   Previous_Employer  \
# 0     NaN     NaN    Finance   A2              NaN                 NaN
# 1     NaN     NaN         HR   A1              NaN                 NaN
# 160  32.0     NaN    Finance   B2              NaN                 NaN
# 182  25.0    Male    Finance   A2              NaN  Supreme Trading Co
# 183  26.0  Female    Finance   A2              NaN   Lkq India Pvt LTD
#
#                            School                     Pu  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 160                           NaN                    NaN
# 182  seventh day adventist school         LBS pu college
# 183               Tgm high school  Jyothirmai Jr college
#
#                                Graduate Post_Graduation Marital_Status  \
# 0                                   NaN             NaN            NaN
# 1                                   NaN             NaN            NaN
# 160                                 NaN             NaN            NaN
# 182                        IDSG College             NaN         Single
# 183  The adoni arts and science college             NaN         Single
#
#      Completion_Rate_Content  Completion_Rate_Form  Days_worked  \
# 0                       0.00                     1          389
# 1                       0.00                     1          370
# 160                     0.00                     1          378
# 182                    55.32                     1          385
# 183                    40.43                     1          385
#
#      Number_of_ Months_RoundUp City_Permanent_Address  PAN_Card  Aadhaar  \
# 0                           13                    NaN       NaN      NaN
# 1                           12                    NaN       NaN      NaN
# 160                         12                    NaN       NaN      NaN
# 182                         13          Chickmagaluru       1.0      1.0
# 183                         13                  Adoni       1.0      1.0
#
#      Passport
# 0         NaN
# 1         NaN
# 160       NaN
# 182       1.0
# 183       0.0

# %%
hr5=hr1.dropna(subset=['Age'])
hr5.head()
# Out:
#      Age  Gender Department Band  Work_Experience  \
# 26  25.0  Female  Insurance  NaN              NaN
# 27  25.0     NaN  Insurance  NaN              NaN
# 28  24.0  Female  Insurance  NaN              NaN
# 29  24.0     NaN  Insurance  NaN              NaN
# 30  25.0    Male  Insurance  NaN              NaN
#
#                Previous_Employer                         School  \
# 26  kRISHNA cATV SYSTEM PVT. LTD       sARVODAYA KANYA VIDHALYA
# 27                           NaN                            NaN
# 28                           NaN                            NaN
# 29                           NaN                            NaN
# 30                           NaN  Govt.co.edu. Sen. sec .school
#
#                             Pu                    Graduate Post_Graduation  \
# 26    SARVODAYA KANYA VIDHALYA     sCHOOL OF OPEN LEARNING             NaN
# 27                         NaN                         NaN             NaN
# 28                         NaN                         NaN             NaN
# 29                         NaN                         NaN             NaN
# 30  Govt.co.edu.sen.sec.school  Motilal Nehru college eve.             NaN
#
#    Marital_Status  Completion_Rate_Form  Number_of_ Months_RoundUp  \
# 26         Single                     1                         13
# 27            NaN                     0                         13
# 28         Single                     0                         13
# 29            NaN                     0                         13
# 30         Single                     1                         13
#
#    City_Permanent_Address  PAN_Card  Aadhaar  Passport
# 26                  Delhi       0.0      1.0       0.0
# 27                    NaN       NaN      NaN       NaN
# 28                  Noida       1.0      1.0       0.0
# 29                    NaN       NaN      NaN       NaN
# 30                  Delhi       1.0      1.0       0.0

# %%
hr6=hr1.dropna(subset=['Work_Experience'])
hr6['Age'].value_counts()
# Out:
# 26.0    317
# 27.0    293
# 25.0    271
# 24.0    259
# 28.0    231
# 23.0    201
# 29.0    189
# 30.0    175
# 31.0    136
# 22.0    124
# 32.0     99
# 33.0     93
# 34.0     66
# 35.0     63
# 21.0     61
# 37.0     41
# 36.0     31
# 38.0     27
# 40.0     16
# 39.0     14
# 20.0      9
# 41.0      9
# 43.0      9
# 42.0      8
# 19.0      7
# 44.0      6
# 45.0      3
# 47.0      3
# 54.0      2
# 46.0      1
# 51.0      1
# 55.0      1
# Name: Age, dtype: int64

# %%
hr5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14549 entries, 26 to 14756
# Data columns (total 17 columns):
# Age                          14549 non-null float64
# Gender                       6591 non-null object
# Department                   14549 non-null object
# Band                         14124 non-null object
# Work_Experience              2766 non-null float64
# Previous_Employer            3921 non-null object
# School                       6288 non-null object
# Pu                           6315 non-null object
# Graduate                     6153 non-null object
# Post_Graduation              1739 non-null object
# Marital_Status               6591 non-null object
# Completion_Rate_Form         14549 non-null int64
# Number_of_ Months_RoundUp    14549 non-null int64
# City_Permanent_Address       6590 non-null object
# PAN_Card                     6591 non-null float64
# Aadhaar                      6591 non-null float64
# Passport                     6548 non-null float64
# dtypes: float64(5), int64(2), object(10)
# memory usage: 2.0+ MB

# %%
plt.figure(figsize=(15,6))
plt.style.use('seaborn-colorblind')
plt.grid(True, alpha=0.5)
sns.kdeplot(hr5.loc[hr5['Completion_Rate_Form'] == 0, 'Age'], label = 'Did not Complete the Form')
sns.kdeplot(hr5.loc[hr5['Completion_Rate_Form'] == 1, 'Age'], label = 'Completed the Form')
plt.xlabel('Age')
plt.xlim(left=0)
plt.ylabel('Density')
plt.title('Age by Form Completion Status');
# Out:
# E:\ana\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.rcParams['figure.figsize'] = (15, 7)
sns.distplot(hr5['Age'], color = 'blue')
plt.title('Distribution of Age among the Employees', fontsize = 24)
plt.xlabel('Age', fontsize = 15)
plt.ylabel('count')
plt.show()
# Out:
# E:\ana\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.axes_style('whitegrid')
sns.catplot('Age', data=hr5, aspect=3, kind='count', hue='Completion_Rate_Form', palette=['Red', 'C0']).set_ylabels('Number of Employees')

# %%
df_Age = pd.DataFrame(columns=["Age", "% of Defaulters"])
i=0
for field in list(hr5['Age'].unique()):
    ratio = hr5[(hr5['Age']==field)&(hr5['Completion_Rate_Form']==0)].shape[0] / hr5[hr5['Age']==field].shape[0]
    df_Age.loc[i] = (field, ratio*100)
    i += 1
    #print("In {}, the ratio of leavers is {:.2f}%".format(field, ratio*100))    

df_Age = df_Age.groupby(by="Age").sum()
df_Age.plot(kind='bar',title='Defaulters by Age in the company (%)')

# %%
plt.figure(figsize=(15,6))
plt.style.use('seaborn-colorblind')
plt.grid(True, alpha=0.5)
sns.kdeplot(hr6.loc[hr6['Completion_Rate_Form'] == 0, 'Work_Experience'], label = 'Did not Complete the Form')
sns.kdeplot(hr6.loc[hr6['Completion_Rate_Form'] == 1, 'Work_Experience'], label = 'Completed the Form')
plt.xlabel('Work_Experience')
plt.xlim(left=0)
plt.ylabel('Density')
plt.title('Work Experience by Form Completion Status');
# Out:
# E:\ana\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# E:\ana\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# E:\ana\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# E:\ana\lib\site-packages\statsmodels\nonparametric\bandwidths.py:20: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)
# E:\ana\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
hr1=hr1.drop(['Work_Experience'],axis=1)

# %%
hr1
# Out:
#         Age  Gender  Department Band               Previous_Employer  \
# 26     25.0  Female   Insurance  NaN    kRISHNA cATV SYSTEM PVT. LTD
# 27     25.0     NaN   Insurance  NaN                             NaN
# 28     24.0  Female   Insurance  NaN                             NaN
# 29     24.0     NaN   Insurance  NaN                             NaN
# 30     25.0    Male   Insurance  NaN                             NaN
# 31     25.0     NaN   Insurance  NaN                             NaN
# 32     25.0     NaN   Insurance  NaN                             NaN
# 33     25.0     NaN   Insurance  NaN                             NaN
# 34     25.0     NaN   Insurance  NaN                             NaN
# 35     25.0     NaN   Insurance  NaN                             NaN
# 36     25.0     NaN   Insurance  NaN                             NaN
# 37     25.0     NaN   Insurance  NaN                             NaN
# 38     26.0    Male   Insurance  NaN                       Cognizant
# 39     27.0    Male   Insurance  NaN                             NaN
# 40     21.0    Male   Insurance  NaN                             NaN
# 41     21.0     NaN   Insurance  NaN                             NaN
# 42     28.0    Male   Insurance  NaN                             NaN
# 43     28.0     NaN   Insurance  NaN                             NaN
# 44     28.0     NaN   Insurance  NaN                             NaN
# 45     30.0    Male   Insurance  NaN           Tech Mahindra Limited
# 46     30.0     NaN   Insurance  NaN                             NaN
# 47     42.0    Male   Insurance  NaN  COGNIZANT TECHNOLOGY SOLUTIONS
# 48     42.0     NaN   Insurance  NaN                             NaN
# 49     34.0    Male   Insurance  NaN         Xerox business services
# 50     26.0  Female   Insurance  NaN                   Wipro Limited
# 51     26.0     NaN   Insurance  NaN                             NaN
# 52     26.0     NaN   Insurance  NaN                             NaN
# 53     25.0    Male   Insurance  NaN                             NaN
# 54     25.0     NaN   Insurance  NaN                             NaN
# 55     25.0     NaN   Analytics  NaN                             NaN
# ...     ...     ...         ...  ...                             ...
# 14727  29.0     NaN     Finance   A1                             NaN
# 14728  29.0     NaN   Insurance   A2                             NaN
# 14729  29.0     NaN   Insurance   A2                             NaN
# 14730  29.0     NaN   Insurance   A1                             NaN
# 14731  29.0     NaN   Insurance   A1                             NaN
# 14732  29.0     NaN   Insurance   A1                             NaN
# 14733  29.0     NaN   Insurance   A1                             NaN
# 14734  29.0     NaN   Insurance   A1                             NaN
# 14735  29.0     NaN   Insurance   A1                             NaN
# 14736  29.0     NaN   Insurance   A1                             NaN
# 14737  29.0     NaN   Insurance   A1                             NaN
# 14738  29.0     NaN   Insurance   A1                             NaN
# 14739  29.0     NaN   Insurance   A1                             NaN
# 14740  29.0     NaN   Insurance   A1                             NaN
# 14741  23.0    Male     Finance   A1                             NaN
# 14742  23.0    Male     Finance   A1                             NaN
# 14743  23.0     NaN   Insurance   A1                             NaN
# 14744  20.0  Female     Finance   A1                             NaN
# 14745  20.0     NaN     Finance   A1                             NaN
# 14746  20.0     NaN  Technology   B1                             NaN
# 14747  20.0     NaN  Technology   B1                             NaN
# 14748  20.0     NaN  Technology   B1                             NaN
# 14749  20.0     NaN  Technology   B1                             NaN
# 14750  20.0     NaN  Technology   B1                             NaN
# 14751  20.0     NaN  Technology   B1                             NaN
# 14752  20.0     NaN   Insurance   A1                             NaN
# 14753  20.0     NaN   Insurance   A2                             NaN
# 14754  22.0    Male   Insurance   A2             WNS global services
# 14755  22.0     NaN   Insurance   A1                             NaN
# 14756  22.0     NaN   Insurance   A1                             NaN
#
#                                                   School  \
# 26                              sARVODAYA KANYA VIDHALYA
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# 30                         Govt.co.edu. Sen. sec .school
# 31                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 34                                                   NaN
# 35                                                   NaN
# 36                                                   NaN
# 37                                                   NaN
# 38     Govt Boys S.S.School No.3, Sarojini Nagar, new...
# 39                                   GOVT. B.S.S. SCHOOL
# 40                                           BSS college
# 41                                                   NaN
# 42                     Bhagatji memorial sch palla delhi
# 43                                                   NaN
# 44                                                   NaN
# 45                            SMT S S D HSS AWAGRAH ETAH
# 46                                                   NaN
# 47                 D. N. HIGH SCHOOL, MUZAFFARPUR, BIHAR
# 48                                                   NaN
# 49                    Gram Panchayata High School Randia
# 50                                Z P highschool zadgaon
# 51                                                   NaN
# 52                                                   NaN
# 53                 S s Hakim ajmal khan urdu high School
# 54                                                   NaN
# 55                                                   NaN
# ...                                                  ...
# 14727                                                NaN
# 14728                                                NaN
# 14729                                                NaN
# 14730                                                NaN
# 14731                                                NaN
# 14732                                                NaN
# 14733                                                NaN
# 14734                                                NaN
# 14735                                                NaN
# 14736                                                NaN
# 14737                                                NaN
# 14738                                                NaN
# 14739                                                NaN
# 14740                                                NaN
# 14741                           S M T High School Kollur
# 14742                                        GBJC Tiptur
# 14743                                                NaN
# 14744                                                NaN
# 14745                                                NaN
# 14746                                                NaN
# 14747                                                NaN
# 14748                                                NaN
# 14749                                                NaN
# 14750                                                NaN
# 14751                                                NaN
# 14752                                                NaN
# 14753                                                NaN
# 14754                                        DAV college
# 14755                                                NaN
# 14756                                                NaN
#
#                                                       Pu  \
# 26                              SARVODAYA KANYA VIDHALYA
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# 30                            Govt.co.edu.sen.sec.school
# 31                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 34                                                   NaN
# 35                                                   NaN
# 36                                                   NaN
# 37                                                   NaN
# 38     Govt Boys S.S.School No.3, Sarojini Nagar, new...
# 39                                   GOVT. B.S.S. SCHOOL
# 40                                      SD Inter college
# 41                                                   NaN
# 42         Jain bharati Mrigavati Vidyalaya Alipur delhi
# 43                                                   NaN
# 44                                                   NaN
# 45                     M K I INTER COLL DHAULESHWAR ETAH
# 46                                                   NaN
# 47                 NITISHWAR COLLEGE, MUZAFFARPUR, BIHAR
# 48                                                   NaN
# 49                        Balikhanda college, Balikhanda
# 50                                  LAMIT dhamangaon rly
# 51                                                   NaN
# 52                                                   NaN
# 53                                         Poona college
# 54                                                   NaN
# 55                                                   NaN
# ...                                                  ...
# 14727                                                NaN
# 14728                                                NaN
# 14729                                                NaN
# 14730                                                NaN
# 14731                                                NaN
# 14732                                                NaN
# 14733                                                NaN
# 14734                                                NaN
# 14735                                                NaN
# 14736                                                NaN
# 14737                                                NaN
# 14738                                                NaN
# 14739                                                NaN
# 14740                                                NaN
# 14741                            S M T PU college Kollur
# 14742                     kalpatharu p u college, tiptur
# 14743                                                NaN
# 14744                                                NaN
# 14745                                                NaN
# 14746                                                NaN
# 14747                                                NaN
# 14748                                                NaN
# 14749                                                NaN
# 14750                                                NaN
# 14751                                                NaN
# 14752                                                NaN
# 14753                                                NaN
# 14754                                        DAV college
# 14755                                                NaN
# 14756                                                NaN
#
#                                            Graduate  \
# 26                          sCHOOL OF OPEN LEARNING
# 27                                              NaN
# 28                                              NaN
# 29                                              NaN
# 30                       Motilal Nehru college eve.
# 31                                              NaN
# 32                                              NaN
# 33                                              NaN
# 34                                              NaN
# 35                                              NaN
# 36                                              NaN
# 37                                              NaN
# 38                           SOL (Delhi University)
# 39                               SUNRISE UNIVERSITY
# 40                               DAV degree college
# 41                                              NaN
# 42       Jagannath institute of managemnet Sciences
# 43                                              NaN
# 44                                              NaN
# 45     SRI MOHAR SINGH DEGREE COLLAGE BASUNDRA ETAH
# 46                                              NaN
# 47            NITISHWAR COLLEGE, MUZAFFARPUR, BIHAR
# 48                                              NaN
# 49       Babamani College +3 Degree, Panasonic, BDK
# 50                    PRMIT &amp;r badnera amravati
# 51                                              NaN
# 52                                              NaN
# 53                                    Poona college
# 54                                              NaN
# 55                                              NaN
# ...                                             ...
# 14727                                           NaN
# 14728                                           NaN
# 14729                                           NaN
# 14730                                           NaN
# 14731                                           NaN
# 14732                                           NaN
# 14733                                           NaN
# 14734                                           NaN
# 14735                                           NaN
# 14736                                           NaN
# 14737                                           NaN
# 14738                                           NaN
# 14739                                           NaN
# 14740                                           NaN
# 14741                   Poorna prajna College Udupi
# 14742                                   gFGC Tiptur
# 14743                                           NaN
# 14744                                           NaN
# 14745                                           NaN
# 14746                                           NaN
# 14747                                           NaN
# 14748                                           NaN
# 14749                                           NaN
# 14750                                           NaN
# 14751                                           NaN
# 14752                                           NaN
# 14753                                           NaN
# 14754                                   DAV college
# 14755                                           NaN
# 14756                                           NaN
#
#                                        Post_Graduation Marital_Status  \
# 26                                                 NaN         Single
# 27                                                 NaN            NaN
# 28                                                 NaN         Single
# 29                                                 NaN            NaN
# 30                                                 NaN         Single
# 31                                                 NaN            NaN
# 32                                                 NaN            NaN
# 33                                                 NaN            NaN
# 34                                                 NaN            NaN
# 35                                                 NaN            NaN
# 36                                                 NaN            NaN
# 37                                                 NaN            NaN
# 38                                                 NaN         Single
# 39                                                 NaN         Single
# 40                                                 NaN         Single
# 41                                                 NaN            NaN
# 42                                                 NaN         Single
# 43                                                 NaN            NaN
# 44                                                 NaN            NaN
# 45                                                 NaN        Married
# 46                                                 NaN            NaN
# 47                                                 NaN        Married
# 48                                                 NaN            NaN
# 49                                                 NaN         Single
# 50                                                 NaN         Single
# 51                                                 NaN            NaN
# 52                                                 NaN            NaN
# 53                                                 NaN         Single
# 54                                                 NaN            NaN
# 55                                                 NaN            NaN
# ...                                                ...            ...
# 14727                                              NaN            NaN
# 14728                                              NaN            NaN
# 14729                                              NaN            NaN
# 14730                                              NaN            NaN
# 14731                                              NaN            NaN
# 14732                                              NaN            NaN
# 14733                                              NaN            NaN
# 14734                                              NaN            NaN
# 14735                                              NaN            NaN
# 14736                                              NaN            NaN
# 14737                                              NaN            NaN
# 14738                                              NaN            NaN
# 14739                                              NaN            NaN
# 14740                                              NaN            NaN
# 14741  Justice K S Hegde Institue Of management, Nitte         Single
# 14742            RNS Institute of technology bangalore         Single
# 14743                                              NaN            NaN
# 14744                                              NaN         Single
# 14745                                              NaN            NaN
# 14746                                              NaN            NaN
# 14747                                              NaN            NaN
# 14748                                              NaN            NaN
# 14749                                              NaN            NaN
# 14750                                              NaN            NaN
# 14751                                              NaN            NaN
# 14752                                              NaN            NaN
# 14753                                              NaN            NaN
# 14754                                              NaN         Single
# 14755                                              NaN            NaN
# 14756                                              NaN            NaN
#
#        Completion_Rate_Form  Number_of_ Months_RoundUp City_Permanent_Address  \
# 26                        1                         13                  Delhi
# 27                        0                         13                    NaN
# 28                        0                         13                  Noida
# 29                        0                         13                    NaN
# 30                        1                         13                  Delhi
# 31                        0                         13                    NaN
# 32                        0                         13                    NaN
# 33                        0                         13                    NaN
# 34                        0                         13                    NaN
# 35                        0                         13                    NaN
# 36                        0                         13                    NaN
# 37                        0                         13                    NaN
# 38                        1                         13                 Almora
# 39                        1                         13                  Delhi
# 40                        1                         13          Muzaffarnagar
# 41                        0                         13                    NaN
# 42                        0                         13              New Delhi
# 43                        0                         13                    NaN
# 44                        0                         13                    NaN
# 45                        1                         13                   Etah
# 46                        0                         13                    NaN
# 47                        1                         13             Samastipur
# 48                        0                         13                    NaN
# 49                        1                         13                Bhadrak
# 50                        1                         13               Amravati
# 51                        0                         13                    NaN
# 52                        0                         13                    NaN
# 53                        0                         13                   Pune
# 54                        0                         13                    NaN
# 55                        0                         13                    NaN
# ...                     ...                        ...                    ...
# 14727                     1                          0                    NaN
# 14728                     1                          0                    NaN
# 14729                     1                          0                    NaN
# 14730                     1                          0                    NaN
# 14731                     1                          0                    NaN
# 14732                     1                          0                    NaN
# 14733                     1                          0                    NaN
# 14734                     1                          0                    NaN
# 14735                     1                          0                    NaN
# 14736                     1                          0                    NaN
# 14737                     1                         -1                    NaN
# 14738                     1                         -1                    NaN
# 14739                     1                         -1                    NaN
# 14740                     1                         -1                    NaN
# 14741                     1                          0                  Udupi
# 14742                     1                          0                 tiptur
# 14743                     1                          0                    NaN
# 14744                     1                          0               Sringeri
# 14745                     1                          0                    NaN
# 14746                     1                         -7                    NaN
# 14747                     1                         -7                    NaN
# 14748                     1                         -7                    NaN
# 14749                     1                         -7                    NaN
# 14750                     1                         -7                    NaN
# 14751                     1                         -7                    NaN
# 14752                     1                          0                    NaN
# 14753                     1                          0                    NaN
# 14754                     1                         -1            Bulandshahr
# 14755                     1                          0                    NaN
# 14756                     1                          0                    NaN
#
#        PAN_Card  Aadhaar  Passport
# 26          0.0      1.0       0.0
# 27          NaN      NaN       NaN
# 28          1.0      1.0       0.0
# 29          NaN      NaN       NaN
# 30          1.0      1.0       0.0
# 31          NaN      NaN       NaN
# 32          NaN      NaN       NaN
# 33          NaN      NaN       NaN
# 34          NaN      NaN       NaN
# 35          NaN      NaN       NaN
# 36          NaN      NaN       NaN
# 37          NaN      NaN       NaN
# 38          1.0      1.0       0.0
# 39          1.0      1.0       0.0
# 40          1.0      1.0       0.0
# 41          NaN      NaN       NaN
# 42          1.0      1.0       1.0
# 43          NaN      NaN       NaN
# 44          NaN      NaN       NaN
# 45          1.0      1.0       0.0
# 46          NaN      NaN       NaN
# 47          1.0      1.0       0.0
# 48          NaN      NaN       NaN
# 49          1.0      1.0       1.0
# 50          1.0      1.0       0.0
# 51          NaN      NaN       NaN
# 52          NaN      NaN       NaN
# 53          1.0      1.0       1.0
# 54          NaN      NaN       NaN
# 55          NaN      NaN       NaN
# ...         ...      ...       ...
# 14727       NaN      NaN       NaN
# 14728       NaN      NaN       NaN
# 14729       NaN      NaN       NaN
# 14730       NaN      NaN       NaN
# 14731       NaN      NaN       NaN
# 14732       NaN      NaN       NaN
# 14733       NaN      NaN       NaN
# 14734       NaN      NaN       NaN
# 14735       NaN      NaN       NaN
# 14736       NaN      NaN       NaN
# 14737       NaN      NaN       NaN
# 14738       NaN      NaN       NaN
# 14739       NaN      NaN       NaN
# 14740       NaN      NaN       NaN
# 14741       1.0      1.0       1.0
# 14742       1.0      1.0       0.0
# 14743       NaN      NaN       NaN
# 14744       1.0      1.0       0.0
# 14745       NaN      NaN       NaN
# 14746       NaN      NaN       NaN
# 14747       NaN      NaN       NaN
# 14748       NaN      NaN       NaN
# 14749       NaN      NaN       NaN
# 14750       NaN      NaN       NaN
# 14751       NaN      NaN       NaN
# 14752       NaN      NaN       NaN
# 14753       NaN      NaN       NaN
# 14754       1.0      1.0       0.0
# 14755       NaN      NaN       NaN
# 14756       NaN      NaN       NaN
#
# [14549 rows x 16 columns]

# %%
hr7=hr1.dropna(subset=['Gender'])
hr7['Gender'].value_counts()
# Out:
# Male      4443
# Female    2148
# Name: Gender, dtype: int64

# %%
hr7['Completion_Rate_Form'].value_counts()
# Out:
# 1    6571
# 0      20
# Name: Completion_Rate_Form, dtype: int64

# %%
sns.axes_style('whitegrid')
sns.catplot('Gender', data=hr7, aspect=3, kind='count', hue='Completion_Rate_Form', palette=['Red', 'C0']).set_ylabels('Number of Employees')

# %%
df_Age = pd.DataFrame(columns=["Gender", "% of Defaulters"])
i=0
for field in list(hr7['Gender'].unique()):
    ratio = hr7[(hr7['Gender']==field)&(hr7['Completion_Rate_Form']==0)].shape[0] / hr7[hr7['Gender']==field].shape[0]
    df_Age.loc[i] = (field, ratio*100)
    i += 1
    #print("In {}, the ratio of leavers is {:.2f}%".format(field, ratio*100))    

df_Age = df_Age.groupby(by="Gender").sum()
df_Age.plot(kind='bar',title='Defaulters by Gender in the company (%)')

# %%
hr8=hr1.dropna(subset=['Band'])
hr8['Band'].value_counts()
# Out:
# A1    10916
# A2     1494
# B1      928
# B2      333
# C1      262
# C2      109
# D1       41
# D2       21
# E1       17
# E2        2
# F         1
# Name: Band, dtype: int64

# %%
hr8['Completion_Rate_Form'].value_counts()
# Out:
# 1    14124
# Name: Completion_Rate_Form, dtype: int64

# %%
sns.axes_style('whitegrid')
sns.catplot('Band', data=hr8, aspect=3, kind='count', hue='Completion_Rate_Form', palette=['Red', 'C0']).set_ylabels('Number of Employees')

# %%
hr1=hr1.drop(['Band'],axis=1)

# %%
hr1
# Out:
#         Age  Gender  Department               Previous_Employer  \
# 26     25.0  Female   Insurance    kRISHNA cATV SYSTEM PVT. LTD
# 27     25.0     NaN   Insurance                             NaN
# 28     24.0  Female   Insurance                             NaN
# 29     24.0     NaN   Insurance                             NaN
# 30     25.0    Male   Insurance                             NaN
# 31     25.0     NaN   Insurance                             NaN
# 32     25.0     NaN   Insurance                             NaN
# 33     25.0     NaN   Insurance                             NaN
# 34     25.0     NaN   Insurance                             NaN
# 35     25.0     NaN   Insurance                             NaN
# 36     25.0     NaN   Insurance                             NaN
# 37     25.0     NaN   Insurance                             NaN
# 38     26.0    Male   Insurance                       Cognizant
# 39     27.0    Male   Insurance                             NaN
# 40     21.0    Male   Insurance                             NaN
# 41     21.0     NaN   Insurance                             NaN
# 42     28.0    Male   Insurance                             NaN
# 43     28.0     NaN   Insurance                             NaN
# 44     28.0     NaN   Insurance                             NaN
# 45     30.0    Male   Insurance           Tech Mahindra Limited
# 46     30.0     NaN   Insurance                             NaN
# 47     42.0    Male   Insurance  COGNIZANT TECHNOLOGY SOLUTIONS
# 48     42.0     NaN   Insurance                             NaN
# 49     34.0    Male   Insurance         Xerox business services
# 50     26.0  Female   Insurance                   Wipro Limited
# 51     26.0     NaN   Insurance                             NaN
# 52     26.0     NaN   Insurance                             NaN
# 53     25.0    Male   Insurance                             NaN
# 54     25.0     NaN   Insurance                             NaN
# 55     25.0     NaN   Analytics                             NaN
# ...     ...     ...         ...                             ...
# 14727  29.0     NaN     Finance                             NaN
# 14728  29.0     NaN   Insurance                             NaN
# 14729  29.0     NaN   Insurance                             NaN
# 14730  29.0     NaN   Insurance                             NaN
# 14731  29.0     NaN   Insurance                             NaN
# 14732  29.0     NaN   Insurance                             NaN
# 14733  29.0     NaN   Insurance                             NaN
# 14734  29.0     NaN   Insurance                             NaN
# 14735  29.0     NaN   Insurance                             NaN
# 14736  29.0     NaN   Insurance                             NaN
# 14737  29.0     NaN   Insurance                             NaN
# 14738  29.0     NaN   Insurance                             NaN
# 14739  29.0     NaN   Insurance                             NaN
# 14740  29.0     NaN   Insurance                             NaN
# 14741  23.0    Male     Finance                             NaN
# 14742  23.0    Male     Finance                             NaN
# 14743  23.0     NaN   Insurance                             NaN
# 14744  20.0  Female     Finance                             NaN
# 14745  20.0     NaN     Finance                             NaN
# 14746  20.0     NaN  Technology                             NaN
# 14747  20.0     NaN  Technology                             NaN
# 14748  20.0     NaN  Technology                             NaN
# 14749  20.0     NaN  Technology                             NaN
# 14750  20.0     NaN  Technology                             NaN
# 14751  20.0     NaN  Technology                             NaN
# 14752  20.0     NaN   Insurance                             NaN
# 14753  20.0     NaN   Insurance                             NaN
# 14754  22.0    Male   Insurance             WNS global services
# 14755  22.0     NaN   Insurance                             NaN
# 14756  22.0     NaN   Insurance                             NaN
#
#                                                   School  \
# 26                              sARVODAYA KANYA VIDHALYA
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# 30                         Govt.co.edu. Sen. sec .school
# 31                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 34                                                   NaN
# 35                                                   NaN
# 36                                                   NaN
# 37                                                   NaN
# 38     Govt Boys S.S.School No.3, Sarojini Nagar, new...
# 39                                   GOVT. B.S.S. SCHOOL
# 40                                           BSS college
# 41                                                   NaN
# 42                     Bhagatji memorial sch palla delhi
# 43                                                   NaN
# 44                                                   NaN
# 45                            SMT S S D HSS AWAGRAH ETAH
# 46                                                   NaN
# 47                 D. N. HIGH SCHOOL, MUZAFFARPUR, BIHAR
# 48                                                   NaN
# 49                    Gram Panchayata High School Randia
# 50                                Z P highschool zadgaon
# 51                                                   NaN
# 52                                                   NaN
# 53                 S s Hakim ajmal khan urdu high School
# 54                                                   NaN
# 55                                                   NaN
# ...                                                  ...
# 14727                                                NaN
# 14728                                                NaN
# 14729                                                NaN
# 14730                                                NaN
# 14731                                                NaN
# 14732                                                NaN
# 14733                                                NaN
# 14734                                                NaN
# 14735                                                NaN
# 14736                                                NaN
# 14737                                                NaN
# 14738                                                NaN
# 14739                                                NaN
# 14740                                                NaN
# 14741                           S M T High School Kollur
# 14742                                        GBJC Tiptur
# 14743                                                NaN
# 14744                                                NaN
# 14745                                                NaN
# 14746                                                NaN
# 14747                                                NaN
# 14748                                                NaN
# 14749                                                NaN
# 14750                                                NaN
# 14751                                                NaN
# 14752                                                NaN
# 14753                                                NaN
# 14754                                        DAV college
# 14755                                                NaN
# 14756                                                NaN
#
#                                                       Pu  \
# 26                              SARVODAYA KANYA VIDHALYA
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# 30                            Govt.co.edu.sen.sec.school
# 31                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 34                                                   NaN
# 35                                                   NaN
# 36                                                   NaN
# 37                                                   NaN
# 38     Govt Boys S.S.School No.3, Sarojini Nagar, new...
# 39                                   GOVT. B.S.S. SCHOOL
# 40                                      SD Inter college
# 41                                                   NaN
# 42         Jain bharati Mrigavati Vidyalaya Alipur delhi
# 43                                                   NaN
# 44                                                   NaN
# 45                     M K I INTER COLL DHAULESHWAR ETAH
# 46                                                   NaN
# 47                 NITISHWAR COLLEGE, MUZAFFARPUR, BIHAR
# 48                                                   NaN
# 49                        Balikhanda college, Balikhanda
# 50                                  LAMIT dhamangaon rly
# 51                                                   NaN
# 52                                                   NaN
# 53                                         Poona college
# 54                                                   NaN
# 55                                                   NaN
# ...                                                  ...
# 14727                                                NaN
# 14728                                                NaN
# 14729                                                NaN
# 14730                                                NaN
# 14731                                                NaN
# 14732                                                NaN
# 14733                                                NaN
# 14734                                                NaN
# 14735                                                NaN
# 14736                                                NaN
# 14737                                                NaN
# 14738                                                NaN
# 14739                                                NaN
# 14740                                                NaN
# 14741                            S M T PU college Kollur
# 14742                     kalpatharu p u college, tiptur
# 14743                                                NaN
# 14744                                                NaN
# 14745                                                NaN
# 14746                                                NaN
# 14747                                                NaN
# 14748                                                NaN
# 14749                                                NaN
# 14750                                                NaN
# 14751                                                NaN
# 14752                                                NaN
# 14753                                                NaN
# 14754                                        DAV college
# 14755                                                NaN
# 14756                                                NaN
#
#                                            Graduate  \
# 26                          sCHOOL OF OPEN LEARNING
# 27                                              NaN
# 28                                              NaN
# 29                                              NaN
# 30                       Motilal Nehru college eve.
# 31                                              NaN
# 32                                              NaN
# 33                                              NaN
# 34                                              NaN
# 35                                              NaN
# 36                                              NaN
# 37                                              NaN
# 38                           SOL (Delhi University)
# 39                               SUNRISE UNIVERSITY
# 40                               DAV degree college
# 41                                              NaN
# 42       Jagannath institute of managemnet Sciences
# 43                                              NaN
# 44                                              NaN
# 45     SRI MOHAR SINGH DEGREE COLLAGE BASUNDRA ETAH
# 46                                              NaN
# 47            NITISHWAR COLLEGE, MUZAFFARPUR, BIHAR
# 48                                              NaN
# 49       Babamani College +3 Degree, Panasonic, BDK
# 50                    PRMIT &amp;r badnera amravati
# 51                                              NaN
# 52                                              NaN
# 53                                    Poona college
# 54                                              NaN
# 55                                              NaN
# ...                                             ...
# 14727                                           NaN
# 14728                                           NaN
# 14729                                           NaN
# 14730                                           NaN
# 14731                                           NaN
# 14732                                           NaN
# 14733                                           NaN
# 14734                                           NaN
# 14735                                           NaN
# 14736                                           NaN
# 14737                                           NaN
# 14738                                           NaN
# 14739                                           NaN
# 14740                                           NaN
# 14741                   Poorna prajna College Udupi
# 14742                                   gFGC Tiptur
# 14743                                           NaN
# 14744                                           NaN
# 14745                                           NaN
# 14746                                           NaN
# 14747                                           NaN
# 14748                                           NaN
# 14749                                           NaN
# 14750                                           NaN
# 14751                                           NaN
# 14752                                           NaN
# 14753                                           NaN
# 14754                                   DAV college
# 14755                                           NaN
# 14756                                           NaN
#
#                                        Post_Graduation Marital_Status  \
# 26                                                 NaN         Single
# 27                                                 NaN            NaN
# 28                                                 NaN         Single
# 29                                                 NaN            NaN
# 30                                                 NaN         Single
# 31                                                 NaN            NaN
# 32                                                 NaN            NaN
# 33                                                 NaN            NaN
# 34                                                 NaN            NaN
# 35                                                 NaN            NaN
# 36                                                 NaN            NaN
# 37                                                 NaN            NaN
# 38                                                 NaN         Single
# 39                                                 NaN         Single
# 40                                                 NaN         Single
# 41                                                 NaN            NaN
# 42                                                 NaN         Single
# 43                                                 NaN            NaN
# 44                                                 NaN            NaN
# 45                                                 NaN        Married
# 46                                                 NaN            NaN
# 47                                                 NaN        Married
# 48                                                 NaN            NaN
# 49                                                 NaN         Single
# 50                                                 NaN         Single
# 51                                                 NaN            NaN
# 52                                                 NaN            NaN
# 53                                                 NaN         Single
# 54                                                 NaN            NaN
# 55                                                 NaN            NaN
# ...                                                ...            ...
# 14727                                              NaN            NaN
# 14728                                              NaN            NaN
# 14729                                              NaN            NaN
# 14730                                              NaN            NaN
# 14731                                              NaN            NaN
# 14732                                              NaN            NaN
# 14733                                              NaN            NaN
# 14734                                              NaN            NaN
# 14735                                              NaN            NaN
# 14736                                              NaN            NaN
# 14737                                              NaN            NaN
# 14738                                              NaN            NaN
# 14739                                              NaN            NaN
# 14740                                              NaN            NaN
# 14741  Justice K S Hegde Institue Of management, Nitte         Single
# 14742            RNS Institute of technology bangalore         Single
# 14743                                              NaN            NaN
# 14744                                              NaN         Single
# 14745                                              NaN            NaN
# 14746                                              NaN            NaN
# 14747                                              NaN            NaN
# 14748                                              NaN            NaN
# 14749                                              NaN            NaN
# 14750                                              NaN            NaN
# 14751                                              NaN            NaN
# 14752                                              NaN            NaN
# 14753                                              NaN            NaN
# 14754                                              NaN         Single
# 14755                                              NaN            NaN
# 14756                                              NaN            NaN
#
#        Completion_Rate_Form  Number_of_ Months_RoundUp City_Permanent_Address  \
# 26                        1                         13                  Delhi
# 27                        0                         13                    NaN
# 28                        0                         13                  Noida
# 29                        0                         13                    NaN
# 30                        1                         13                  Delhi
# 31                        0                         13                    NaN
# 32                        0                         13                    NaN
# 33                        0                         13                    NaN
# 34                        0                         13                    NaN
# 35                        0                         13                    NaN
# 36                        0                         13                    NaN
# 37                        0                         13                    NaN
# 38                        1                         13                 Almora
# 39                        1                         13                  Delhi
# 40                        1                         13          Muzaffarnagar
# 41                        0                         13                    NaN
# 42                        0                         13              New Delhi
# 43                        0                         13                    NaN
# 44                        0                         13                    NaN
# 45                        1                         13                   Etah
# 46                        0                         13                    NaN
# 47                        1                         13             Samastipur
# 48                        0                         13                    NaN
# 49                        1                         13                Bhadrak
# 50                        1                         13               Amravati
# 51                        0                         13                    NaN
# 52                        0                         13                    NaN
# 53                        0                         13                   Pune
# 54                        0                         13                    NaN
# 55                        0                         13                    NaN
# ...                     ...                        ...                    ...
# 14727                     1                          0                    NaN
# 14728                     1                          0                    NaN
# 14729                     1                          0                    NaN
# 14730                     1                          0                    NaN
# 14731                     1                          0                    NaN
# 14732                     1                          0                    NaN
# 14733                     1                          0                    NaN
# 14734                     1                          0                    NaN
# 14735                     1                          0                    NaN
# 14736                     1                          0                    NaN
# 14737                     1                         -1                    NaN
# 14738                     1                         -1                    NaN
# 14739                     1                         -1                    NaN
# 14740                     1                         -1                    NaN
# 14741                     1                          0                  Udupi
# 14742                     1                          0                 tiptur
# 14743                     1                          0                    NaN
# 14744                     1                          0               Sringeri
# 14745                     1                          0                    NaN
# 14746                     1                         -7                    NaN
# 14747                     1                         -7                    NaN
# 14748                     1                         -7                    NaN
# 14749                     1                         -7                    NaN
# 14750                     1                         -7                    NaN
# 14751                     1                         -7                    NaN
# 14752                     1                          0                    NaN
# 14753                     1                          0                    NaN
# 14754                     1                         -1            Bulandshahr
# 14755                     1                          0                    NaN
# 14756                     1                          0                    NaN
#
#        PAN_Card  Aadhaar  Passport
# 26          0.0      1.0       0.0
# 27          NaN      NaN       NaN
# 28          1.0      1.0       0.0
# 29          NaN      NaN       NaN
# 30          1.0      1.0       0.0
# 31          NaN      NaN       NaN
# 32          NaN      NaN       NaN
# 33          NaN      NaN       NaN
# 34          NaN      NaN       NaN
# 35          NaN      NaN       NaN
# 36          NaN      NaN       NaN
# 37          NaN      NaN       NaN
# 38          1.0      1.0       0.0
# 39          1.0      1.0       0.0
# 40          1.0      1.0       0.0
# 41          NaN      NaN       NaN
# 42          1.0      1.0       1.0
# 43          NaN      NaN       NaN
# 44          NaN      NaN       NaN
# 45          1.0      1.0       0.0
# 46          NaN      NaN       NaN
# 47          1.0      1.0       0.0
# 48          NaN      NaN       NaN
# 49          1.0      1.0       1.0
# 50          1.0      1.0       0.0
# 51          NaN      NaN       NaN
# 52          NaN      NaN       NaN
# 53          1.0      1.0       1.0
# 54          NaN      NaN       NaN
# 55          NaN      NaN       NaN
# ...         ...      ...       ...
# 14727       NaN      NaN       NaN
# 14728       NaN      NaN       NaN
# 14729       NaN      NaN       NaN
# 14730       NaN      NaN       NaN
# 14731       NaN      NaN       NaN
# 14732       NaN      NaN       NaN
# 14733       NaN      NaN       NaN
# 14734       NaN      NaN       NaN
# 14735       NaN      NaN       NaN
# 14736       NaN      NaN       NaN
# 14737       NaN      NaN       NaN
# 14738       NaN      NaN       NaN
# 14739       NaN      NaN       NaN
# 14740       NaN      NaN       NaN
# 14741       1.0      1.0       1.0
# 14742       1.0      1.0       0.0
# 14743       NaN      NaN       NaN
# 14744       1.0      1.0       0.0
# 14745       NaN      NaN       NaN
# 14746       NaN      NaN       NaN
# 14747       NaN      NaN       NaN
# 14748       NaN      NaN       NaN
# 14749       NaN      NaN       NaN
# 14750       NaN      NaN       NaN
# 14751       NaN      NaN       NaN
# 14752       NaN      NaN       NaN
# 14753       NaN      NaN       NaN
# 14754       1.0      1.0       0.0
# 14755       NaN      NaN       NaN
# 14756       NaN      NaN       NaN
#
# [14549 rows x 15 columns]

# %%
hr9=hr1.dropna(subset=['Previous_Employer'])
hr9['Completion_Rate_Form'].value_counts()
# Out:
# 1    3915
# 0       6
# Name: Completion_Rate_Form, dtype: int64

# %%
hr10=hr1.dropna(subset=['School'])
hr10['Completion_Rate_Form'].value_counts()
# Out:
# 1    6278
# 0      10
# Name: Completion_Rate_Form, dtype: int64

# %%
hr11=hr1.dropna(subset=['Pu'])
hr11['Completion_Rate_Form'].value_counts()
# Out:
# 1    6305
# 0      10
# Name: Completion_Rate_Form, dtype: int64

# %%
hr12=hr1.dropna(subset=['Graduate'])
hr12['Completion_Rate_Form'].value_counts()
# Out:
# 1    6146
# 0       7
# Name: Completion_Rate_Form, dtype: int64

# %%
hr13=hr1.dropna(subset=['Post_Graduation'])
hr13['Completion_Rate_Form'].value_counts()
# Out:
# 1    1738
# 0       1
# Name: Completion_Rate_Form, dtype: int64

# %%
hr14=hr1.dropna(subset=['Marital_Status'])
hr14['Completion_Rate_Form'].value_counts()
# Out:
# 1    6571
# 0      20
# Name: Completion_Rate_Form, dtype: int64

# %%
hr16=hr1.dropna(subset=['City_Permanent_Address'])
hr16['Completion_Rate_Form'].value_counts()
# Out:
# 1    6570
# 0      20
# Name: Completion_Rate_Form, dtype: int64

# %%
hr15=hr1.dropna(subset=['Passport'])
hr15['Completion_Rate_Form'].value_counts()
# Out:
# 1    6529
# 0      19
# Name: Completion_Rate_Form, dtype: int64

# %%
hr15['Number_of_ Months_RoundUp'].value_counts()
# Out:
#  3     1047
#  5      901
#  4      805
#  2      582
#  0      541
#  6      503
#  1      477
#  7      410
#  8      306
#  12     239
#  10     230
#  9      181
#  11     166
#  13      90
# -1       52
# -2       17
# -3        1
# Name: Number_of_ Months_RoundUp, dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.style.use('seaborn-colorblind')
plt.grid(True, alpha=0.5)
sns.kdeplot(hr15.loc[hr15['Completion_Rate_Form'] == 0, 'Number_of_ Months_RoundUp'], label = 'Did not Complete the Form')
sns.kdeplot(hr15.loc[hr15['Completion_Rate_Form'] == 1, 'Number_of_ Months_RoundUp'], label = 'Completed the Form')
plt.xlabel('Number_of_ Months_RoundUp')
plt.xlim(left=-7)
plt.ylabel('Density')
plt.title('Number_of_ Months_RoundUp by Form Completion Status');
# Out:
# E:\ana\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.rcParams['figure.figsize'] = (15, 7)
sns.distplot(hr15['Number_of_ Months_RoundUp'], color = 'blue')
plt.title('Distribution of Months worked among the Employees', fontsize = 24)
plt.xlabel('Number_of_ Months_RoundUp', fontsize = 15)
plt.ylabel('count')
plt.show()
# Out:
# E:\ana\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.axes_style('whitegrid')
sns.catplot('Number_of_ Months_RoundUp', data=hr15, aspect=3, kind='count', hue='Completion_Rate_Form', palette=['Red', 'C0']).set_ylabels('Number of Employees')

# %%
df_Age = pd.DataFrame(columns=["Number_of_ Months_RoundUp", "% of Defaulters"])
i=0
for field in list(hr15['Number_of_ Months_RoundUp'].unique()):
    ratio = hr15[(hr15['Number_of_ Months_RoundUp']==field)&(hr15['Completion_Rate_Form']==0)].shape[0] / hr15[hr15['Number_of_ Months_RoundUp']==field].shape[0]
    df_Age.loc[i] = (field, ratio*100)
    i += 1
    #print("In {}, the ratio of leavers is {:.2f}%".format(field, ratio*100))    

df_Age = df_Age.groupby(by="Number_of_ Months_RoundUp").sum()
df_Age.plot(kind='bar',title='Defaulters by Months Worked in the company (%)')

# %%
hr_new=hr1.drop(['Previous_Employer'],axis=1)
hr_new=hr_new.drop(['School'],axis=1)
hr_new=hr_new.drop(['Pu'],axis=1)
hr_new=hr_new.drop(['Graduate'],axis=1)
hr_new=hr_new.drop(['Post_Graduation'],axis=1)
hr_new=hr_new.drop(['Marital_Status'],axis=1)
hr_new=hr_new.drop(['Passport'],axis=1)
hr_new=hr_new.drop(['Aadhaar'],axis=1)
hr_new=hr_new.drop(['PAN_Card'],axis=1)
hr_new=hr_new.drop(['City_Permanent_Address'],axis=1)

# %%
hr_new.isnull().sum()
hr_new1=hr_new.dropna()

# %%
hr_new1.count()
# Out:
# Age                          6591
# Gender                       6591
# Department                   6591
# Completion_Rate_Form         6591
# Number_of_ Months_RoundUp    6591
# dtype: int64

# %%
sns.axes_style('whitegrid')
sns.catplot('Department', data=hr_new, aspect=3, kind='count', hue='Completion_Rate_Form', palette=['Red', 'C0']).set_ylabels('Number of Employees')

# %%
df_dep = pd.DataFrame(columns=["Department", "% of Defaulters"])
i=0
for field in list(hr_new['Department'].unique()):
    ratio = hr_new[(hr_new['Department']==field)&(hr_new['Completion_Rate_Form']==0)].shape[0] / hr_new[hr_new['Department']==field].shape[0]
    df_dep.loc[i] = (field, ratio*100)
    i += 1
    #print("In {}, the ratio of leavers is {:.2f}%".format(field, ratio*100))    

df_dep = df_dep.groupby(by="Department").sum()
df_dep.plot(kind='bar',title='Defaulters by Department in the company (%)')

# %%
hr_new
# Out:
#         Age  Gender  Department  Completion_Rate_Form  \
# 26     25.0  Female   Insurance                     1
# 27     25.0     NaN   Insurance                     0
# 28     24.0  Female   Insurance                     0
# 29     24.0     NaN   Insurance                     0
# 30     25.0    Male   Insurance                     1
# 31     25.0     NaN   Insurance                     0
# 32     25.0     NaN   Insurance                     0
# 33     25.0     NaN   Insurance                     0
# 34     25.0     NaN   Insurance                     0
# 35     25.0     NaN   Insurance                     0
# 36     25.0     NaN   Insurance                     0
# 37     25.0     NaN   Insurance                     0
# 38     26.0    Male   Insurance                     1
# 39     27.0    Male   Insurance                     1
# 40     21.0    Male   Insurance                     1
# 41     21.0     NaN   Insurance                     0
# 42     28.0    Male   Insurance                     0
# 43     28.0     NaN   Insurance                     0
# 44     28.0     NaN   Insurance                     0
# 45     30.0    Male   Insurance                     1
# 46     30.0     NaN   Insurance                     0
# 47     42.0    Male   Insurance                     1
# 48     42.0     NaN   Insurance                     0
# 49     34.0    Male   Insurance                     1
# 50     26.0  Female   Insurance                     1
# 51     26.0     NaN   Insurance                     0
# 52     26.0     NaN   Insurance                     0
# 53     25.0    Male   Insurance                     0
# 54     25.0     NaN   Insurance                     0
# 55     25.0     NaN   Analytics                     0
# ...     ...     ...         ...                   ...
# 14727  29.0     NaN     Finance                     1
# 14728  29.0     NaN   Insurance                     1
# 14729  29.0     NaN   Insurance                     1
# 14730  29.0     NaN   Insurance                     1
# 14731  29.0     NaN   Insurance                     1
# 14732  29.0     NaN   Insurance                     1
# 14733  29.0     NaN   Insurance                     1
# 14734  29.0     NaN   Insurance                     1
# 14735  29.0     NaN   Insurance                     1
# 14736  29.0     NaN   Insurance                     1
# 14737  29.0     NaN   Insurance                     1
# 14738  29.0     NaN   Insurance                     1
# 14739  29.0     NaN   Insurance                     1
# 14740  29.0     NaN   Insurance                     1
# 14741  23.0    Male     Finance                     1
# 14742  23.0    Male     Finance                     1
# 14743  23.0     NaN   Insurance                     1
# 14744  20.0  Female     Finance                     1
# 14745  20.0     NaN     Finance                     1
# 14746  20.0     NaN  Technology                     1
# 14747  20.0     NaN  Technology                     1
# 14748  20.0     NaN  Technology                     1
# 14749  20.0     NaN  Technology                     1
# 14750  20.0     NaN  Technology                     1
# 14751  20.0     NaN  Technology                     1
# 14752  20.0     NaN   Insurance                     1
# 14753  20.0     NaN   Insurance                     1
# 14754  22.0    Male   Insurance                     1
# 14755  22.0     NaN   Insurance                     1
# 14756  22.0     NaN   Insurance                     1
#
#        Number_of_ Months_RoundUp
# 26                            13
# 27                            13
# 28                            13
# 29                            13
# 30                            13
# 31                            13
# 32                            13
# 33                            13
# 34                            13
# 35                            13
# 36                            13
# 37                            13
# 38                            13
# 39                            13
# 40                            13
# 41                            13
# 42                            13
# 43                            13
# 44                            13
# 45                            13
# 46                            13
# 47                            13
# 48                            13
# 49                            13
# 50                            13
# 51                            13
# 52                            13
# 53                            13
# 54                            13
# 55                            13
# ...                          ...
# 14727                          0
# 14728                          0
# 14729                          0
# 14730                          0
# 14731                          0
# 14732                          0
# 14733                          0
# 14734                          0
# 14735                          0
# 14736                          0
# 14737                         -1
# 14738                         -1
# 14739                         -1
# 14740                         -1
# 14741                          0
# 14742                          0
# 14743                          0
# 14744                          0
# 14745                          0
# 14746                         -7
# 14747                         -7
# 14748                         -7
# 14749                         -7
# 14750                         -7
# 14751                         -7
# 14752                          0
# 14753                          0
# 14754                         -1
# 14755                          0
# 14756                          0
#
# [14549 rows x 5 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
hr_new['Department'].unique()
# Out:
# array(['Insurance', 'Analytics', 'Travels', 'Utilities', 'Finance',
#        'Healthcare', 'HR', 'Technology', 'Sales'], dtype=object)

# %%
plt.figure(figsize=(12,6))
sns.heatmap(hr_new.corr(method='spearman'), cmap='coolwarm', annot=True)
plt.tight_layout()
plt.show()

# %%
g = sns.factorplot(x="Age", y="Completion_Rate_Form",
                   hue="Gender", row="Department",
                    data=hr_new1,
                    orient="h", size=2, aspect=3.5, palette="Set3",
                    kind="violin", split=True, cut=0, bw=.2)
plt.show()
# Out:
# E:\ana\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# E:\ana\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# E:\ana\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
g = sns.factorplot(x="Number_of_ Months_RoundUp", y="Completion_Rate_Form",
                   hue="Gender", row="Department",
                    data=hr_new1,
                    orient="h", size=2, aspect=3.5, palette="Set3",
                    kind="violin", split=True, cut=0, bw=.2)
plt.show()
# Out:
# E:\ana\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# E:\ana\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# E:\ana\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
hr_new.iloc[1][1]
# Out:
# nan

# %%
hr_new['Department']=hr_new['Department'].astype('category')
hr_new['Department']=hr_new['Department'].cat.reorder_categories(['Insurance', 'Analytics', 'Travels', 'Utilities', 'Finance','Healthcare', 'HR', 'Technology', 'Sales'])
hr_new['Department']=hr_new['Department'].cat.codes

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(hr_new['Age'],hr_new['Department'],hr_new['Completion_Rate_Form'], s=30)
plt.ylabel('Departemnt')
plt.show()

# %%
hr_new['Department'].value_counts()
# Out:
# 0    6087
# 5    2457
# 4    2108
# 2    1377
# 1    1072
# 3     699
# 8     377
# 6     208
# 7     164
# Name: Department, dtype: int64
