# %%
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter

# %%
#data = pd.read_csv('P:/TYDY/Data.csv')
data = pd.read_csv('P:/TYDY/Demo_Data_Dep_Sorted.csv')
data[['School', 'Pu', 'Graduate', 'Post_Graduation']] = np.where(data[['School', 'Pu', 'Graduate', 'Post_Graduation']].isnull(), 0, 1)

# %%
data
# Out:
#         Age  Gender  Department Band  Work_Experience  \
# 0       NaN     NaN     Finance   A2              NaN
# 1       NaN     NaN          HR   A1              NaN
# 2       NaN     NaN     Travels  NaN              NaN
# 3       NaN     NaN     Travels  NaN              NaN
# 4       NaN     NaN     Travels  NaN              NaN
# 5       NaN     NaN     Travels  NaN              NaN
# 6       NaN     NaN     Travels  NaN              NaN
# 7       NaN     NaN     Travels  NaN              NaN
# 8       NaN     NaN     Travels  NaN              NaN
# 9       NaN     NaN     Travels  NaN              NaN
# 10      NaN     NaN     Travels  NaN              NaN
# 11      NaN     NaN     Travels  NaN              NaN
# 12      NaN     NaN     Travels  NaN              NaN
# 13      NaN     NaN     Travels  NaN              NaN
# 14      NaN     NaN     Travels  NaN              NaN
# 15      NaN     NaN     Travels  NaN              NaN
# ...

# %%
data.head()
# Out:
#    Age Gender Department Band  Work_Experience Previous_Employer  School  Pu  \
# 0  NaN    NaN    Finance   A2              NaN               NaN       0   0
# 1  NaN    NaN         HR   A1              NaN               NaN       0   0
# 2  NaN    NaN    Travels  NaN              NaN               NaN       0   0
# 3  NaN    NaN    Travels  NaN              NaN               NaN       0   0
# 4  NaN    NaN    Travels  NaN              NaN               NaN       0   0
#
#    Graduate  Post_Graduation   ...     start_date    end_date  Days_worked  \
# 0         0                0   ...     11/15/2018  12-09-2019          389
# 1         0                0   ...     12-04-2018  12-09-2019          370
# 2         0                0   ...     11-12-2018  12-09-2019          392
# 3         0                0   ...     11-12-2018  12-09-2019          392
# 4         0                0   ...     11/14/2018  12-09-2019          390
#
# ...

# %%
data.describe(include = 'all')
# Out:
#                  Age Gender Department   Band  Work_Experience  \
# count   14766.000000   6691      14792  14336      2816.000000
# unique           NaN      2          9     11              NaN
# top              NaN   Male  Insurance     A1              NaN
# freq             NaN   4510       6162  11060              NaN
# mean       26.166463    NaN        NaN    NaN         3.682173
# std         6.539369    NaN        NaN    NaN         3.066147
# min         0.000000    NaN        NaN    NaN         0.000000
# 25%        23.000000    NaN        NaN    NaN         2.000000
# 50%        25.000000    NaN        NaN    NaN         3.000000
# 75%        28.000000    NaN        NaN    NaN         5.000000
# max       118.000000    NaN        NaN    NaN        20.000000
#
#        Previous_Employer        School            Pu      Graduate  \
# count               3988  14792.000000  14792.000000  14792.000000
# unique              2959           NaN           NaN           NaN
# ...

# %%
data1=data.drop(['School'],axis=1)
data1=data1.drop(['Pu'],axis=1)
data1=data1.drop(['Graduate'],axis=1)
data1=data1.drop(['Post_Graduation'],axis=1)
data2=data.drop(['start_date'],axis=1)
data2=data2.drop(['end_date'],axis=1)
data2=data2.drop(['Days_worked'],axis=1)
data2=data2.drop(['Number_of_Months_Exact'],axis=1)
data2=data2.drop(['Completion_Rate_Form'],axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14792 entries, 0 to 14791
# Data columns (total 23 columns):
# Age                         14766 non-null float64
# Gender                      6691 non-null object
# Department                  14792 non-null object
# Band                        14336 non-null object
# Work_Experience             2816 non-null float64
# Previous_Employer           3988 non-null object
# School                      14792 non-null int64
# Pu                          14792 non-null int64
# Graduate                    14792 non-null int64
# Post_Graduation             14792 non-null int64
# Marital_Status              6691 non-null object
# Completion_Rate_Content     14792 non-null float64
# Completion_Rate_Form        14792 non-null int64
# start_date                  14792 non-null object
# end_date                    14792 non-null object
# Days_worked                 14792 non-null int64
# Number_of_Months_Exact      14792 non-null float64
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(data.corr(method='spearman'), cmap='coolwarm', annot=True)
plt.tight_layout()
plt.show()

# %%
data.isnull().any()
# Out:
# Age                          True
# Gender                       True
# Department                  False
# Band                         True
# Work_Experience              True
# Previous_Employer            True
# School                      False
# Pu                          False
# Graduate                    False
# Post_Graduation             False
# Marital_Status               True
# Completion_Rate_Content     False
# Completion_Rate_Form        False
# start_date                  False
# end_date                    False
# Days_worked                 False
# Number_of_Months_Exact      False
# Number_of_Months_RoundUp    False
# State_Permanent_Address      True
# City_Permanent_Address       True
# PAN_Card                     True
# Aadhaar                      True
# Passport                     True
# dtype: bool

# %%
data.isnull().sum()
# Out:
# Age                            26
# Gender                       8101
# Department                      0
# Band                          456
# Work_Experience             11976
# Previous_Employer           10804
# School                          0
# Pu                              0
# Graduate                        0
# Post_Graduation                 0
# Marital_Status               8101
# Completion_Rate_Content         0
# Completion_Rate_Form            0
# start_date                      0
# end_date                        0
# Days_worked                     0
# Number_of_Months_Exact          0
# Number_of_Months_RoundUp        0
# State_Permanent_Address     13550
# City_Permanent_Address       8102
# PAN_Card                     8101
# Aadhaar                      8101
# Passport                     8146
# dtype: int64

# %%
data['Department'].unique()
# Out:
# array(['Finance', 'HR', 'Travels', 'Insurance', 'Analytics', 'Utilities',
#        'Healthcare', 'Technology', 'Sales'], dtype=object)

# %%
data['Department'].value_counts()
# Out:
# Insurance     6162
# Healthcare    2486
# Finance       2149
# Travels       1411
# Analytics     1094
# Utilities      713
# Sales          395
# HR             212
# Technology     170
# Name: Department, dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# Male      4510
# Female    2181
# Name: Gender, dtype: int64

# %%
data['Band'].value_counts()
# Out:
# A1    11060
# A2     1517
# B1      944
# B2      341
# C1      276
# C2      113
# D1       42
# D2       21
# E1       19
# E2        2
# F         1
# Name: Band, dtype: int64

# %%
"""data3=data2.dropna()
data3
plt.figure(figsize=(7,7))
sns.heatmap(data3.corr(method='spearman'), cmap='coolwarm', annot=True)
plt.tight_layout()
plt.show()"""
# Out:
# "data3=data2.dropna()\ndata3\nplt.figure(figsize=(7,7))\nsns.heatmap(data3.corr(method='spearman'), cmap='coolwarm', annot=True)\nplt.tight_layout()\nplt.show()"

# %%
data_age=data.dropna(subset=['Age'])
data_age = data_age[data_age['Age'] <=50 ]
data_age = data_age[data_age['Age'] >=18 ]
#data3=data2
plt.rcParams['figure.figsize']=(15,7)
sns.distplot(data_age['Age'], color = 'blue')
plt.title('Distribution of Age', fontsize = 30)
plt.xlabel('Age', fontsize = 24)
plt.ylabel('count')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.heatmap(data.corr(method='spearman'), cmap='coolwarm', annot=True)
plt.tight_layout()
plt.show()

# %%
data.groupby('Department').mean()
# Out:
#                   Age  Work_Experience    School        Pu  Graduate  \
# Department
# Analytics   26.220293         3.786713  0.748629  0.751371  0.759598
# Finance     26.227188         3.482289  0.717543  0.720800  0.719870
# HR          26.981043         4.595745  0.396226  0.396226  0.391509
# Healthcare  25.634352         2.577778  0.128319  0.131537  0.130330
# Insurance   26.141049         3.430755  0.375203  0.376177  0.359948
# Sales       29.212658         6.201149  0.630380  0.632911  0.615190
# Technology  30.247059         6.883333  0.535294  0.529412  0.529412
# Travels     25.255764         3.232323  0.461375  0.462084  0.425939
# Utilities   26.847125         2.938272  0.440393  0.444600  0.437588
#
#             Post_Graduation  Completion_Rate_Content  Completion_Rate_Form  \
# Department
# Analytics          0.291590                40.538327              0.981718
# Finance            0.286645                29.988343              0.972080
# ...

# %%
data.groupby('Gender').mean()
# Out:
#               Age  Work_Experience    School        Pu  Graduate  \
# Gender
# Female  25.469509         3.419169  0.942687  0.946813  0.930307
# Male    26.371175         3.798765  0.950776  0.954767  0.928381
#
#         Post_Graduation  Completion_Rate_Content  Completion_Rate_Form  \
# Gender
# Female         0.325539                32.147795              0.996332
# Male           0.233481                34.689503              0.997339
#
#         Days_worked  Number_of_Months_Exact  Number_of_Months_RoundUp  \
# Gender
# Female   142.404860                4.681059                  4.707015
# Male     142.208869                4.674601                  4.687361
#
#         PAN_Card   Aadhaar  Passport
# Gender
# Female  0.913801  0.995873  0.304895
# Male    0.950776  0.994235  0.356869

# %%
data.groupby('Band').mean()
# Out:
#             Age  Work_Experience    School        Pu  Graduate  \
# Band
# A1    25.696265         3.004442  0.381193  0.383273  0.368264
# A2    26.390501         3.462733  0.684904  0.687541  0.691496
# B1    26.811441         4.653285  0.593220  0.594280  0.597458
# B2    29.659824         5.687075  0.633431  0.630499  0.633431
# C1    30.775362         6.418367  0.634058  0.637681  0.637681
# C2    31.619469         9.057143  0.504425  0.504425  0.504425
# D1    33.809524         8.666667  0.595238  0.595238  0.571429
# D2    32.333333        11.000000  0.428571  0.428571  0.428571
# E1    27.052632        13.500000  0.157895  0.157895  0.157895
# E2    23.000000              NaN  0.000000  0.000000  0.000000
# F     28.000000              NaN  0.000000  0.000000  0.000000
#
#       Post_Graduation  Completion_Rate_Content  Completion_Rate_Form  \
# Band
# A1           0.079837                16.878574                   1.0
# ...

# %%
data.groupby('Number_of_Months_RoundUp').mean()
# Out:
#                                 Age  Work_Experience    School        Pu  \
# Number_of_Months_RoundUp
# -7                        20.000000              NaN  0.000000  0.000000
# -3                        24.666667         2.000000  0.333333  0.333333
# -2                        27.760000         6.388889  0.720000  0.720000
# -1                        27.392857         4.680000  0.607143  0.607143
#  0                        26.227605         3.817010  0.488117  0.491773
#  1                        26.705458         4.070769  0.481977  0.486097
#  2                        25.249814         4.264305  0.430483  0.428996
#  3                        25.731661         3.718220  0.485092  0.488405
#  4                        25.802826         3.620438  0.511882  0.515093
#  5                        26.296338         3.225694  0.508732  0.507606
#  6                        26.137594         2.835165  0.362406  0.363158
# ...

# %%
"""plt.rcParams['figure.figsize'] = (101, 95)
sns.distplot(data1['Days_worked'], color = 'blue')
plt.title('Distribution of Training Score among the Employees', fontsize = 30)
plt.xlabel('Average Training Score', fontsize = 20)
plt.ylabel('count')
plt.show()"""
# Out:
# "plt.rcParams['figure.figsize'] = (101, 95)\nsns.distplot(data1['Days_worked'], color = 'blue')\nplt.title('Distribution of Training Score among the Employees', fontsize = 30)\nplt.xlabel('Average Training Score', fontsize = 20)\nplt.ylabel('count')\nplt.show()"

# %%
"""from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopword = set(STOPWORDS)

wordcloud = WordCloud(background_color = 'white', stopwords = stopword).generate(str(data1['Department'].unique()))

plt.rcParams['figure.figsize'] = (12, 8)
print(wordcloud)
plt.imshow(wordcloud)
plt.title('Most Popular Departments', fontsize = 30)
plt.axis('off')
plt.show()"""
# Out:
# "from wordcloud import WordCloud\nfrom wordcloud import STOPWORDS\n\nstopword = set(STOPWORDS)\n\nwordcloud = WordCloud(background_color = 'white', stopwords = stopword).generate(str(data1['Department'].unique()))\n\nplt.rcParams['figure.figsize'] = (12, 8)\nprint(wordcloud)\nplt.imshow(wordcloud)\nplt.title('Most Popular Departments', fontsize = 30)\nplt.axis('off')\nplt.show()"

# %%
data_month=data.dropna(subset=['Number_of_Months_RoundUp'])
data_month = data_month[data_month['Number_of_Months_RoundUp'] <=15 ]
data_month = data_month[data_month['Number_of_Months_RoundUp'] >=0 ]
#data3=data2

#data3=data2

# %%
plt.rcParams['figure.figsize']=(15,7)
sns.distplot(data_month['Number_of_Months_RoundUp'], color = 'blue')
plt.title('Distribution of Number_of_Months', fontsize = 30)
plt.xlabel('Number_of_Months', fontsize = 24)
plt.ylabel('count')
plt.show()

# %%
plt.rcParams['figure.figsize']=(15,7)
sns.distplot(data_we['Work_Experience'], color = 'blue')
plt.title('Work_Experience Density Plot', fontsize = 30)
plt.xlabel('Work_Experience', fontsize = 24)
plt.ylabel('count')
plt.show()

# %%
data_month_age=data_month.dropna(subset=['Age'])
plt.rcParams['figure.figsize']=(25,7)
sns.barplot(x=data_month_age['Number_of_Months_RoundUp'],y=data_month_age['Age'], color = 'blue')
plt.title('Number_of_Months_RoundUp VS Age', fontsize = 30)
plt.xlabel('Number_of_Months_RoundUp', fontsize = 15)
plt.ylabel('Age', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize']=(25,7)
sns.barplot(x=data_age['Age'],y=data_age['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content Vs Age', fontsize = 30)
plt.xlabel('Age', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
"""plt.rcParams['figure.figsize']=(24,7)
sns.barplot(x=data2['Age'],y=data2['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS Age', fontsize = 30)
plt.xlabel('Age', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()"""
# Out:
# "plt.rcParams['figure.figsize']=(24,7)\nsns.barplot(x=data2['Age'],y=data2['Completion_Rate_Content'], color = 'blue')\nplt.title('Completion_Rate_Content VS Age', fontsize = 30)\nplt.xlabel('Age', fontsize = 15)\nplt.ylabel('Completion_Rate_Content', fontsize = 15)\nplt.show()"

# %%
data_we=data.dropna(subset=['Work_Experience'])
#data_month = data_month[data_month['Number_of_Months_RoundUp'] <=25 ]
#data_month = data_month[data_month['Number_of_Months_RoundUp'] >=0 ]

plt.rcParams['figure.figsize']=(20,7)
sns.barplot(x=data_we['Work_Experience'],y=data_we['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS Work_Experience', fontsize = 30)
plt.xlabel('Work_Experience', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
data_status=data.dropna(subset=['Marital_Status'])


plt.rcParams['figure.figsize']=(20,7)
sns.barplot(x=data_status['Marital_Status'],y=data_status['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS Marital_Status', fontsize = 30)
plt.xlabel('Work_Experience', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
data_gender=data.dropna(subset=['Gender'])

plt.rcParams['figure.figsize']=(2,5)
sns.barplot(x=data_gender['Gender'],y=data_gender['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS Gender', fontsize = 30)
plt.xlabel('Gender', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
data_roundup=data.dropna(subset=['Number_of_Months_RoundUp'])
plt.rcParams['figure.figsize']=(15,7)
sns.barplot(x=data_roundup['Number_of_Months_RoundUp'],y=data_roundup['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS Number_of_Months_RoundUp', fontsize = 30)
plt.xlabel('Number_of_Months_RoundUp', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
data_pan=data.dropna(subset=['PAN_Card'])

plt.rcParams['figure.figsize']=(5,10)
sns.barplot(x=data_pan['PAN_Card'],y=data_pan['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS PAN_Card', fontsize = 30)
plt.xlabel('Number_of_Months_RoundUp', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
data_aadhar=data.dropna(subset=['Aadhaar'])
plt.rcParams['figure.figsize']=(5,10)
sns.barplot(x=data_aadhar['Aadhaar'],y=data_aadhar['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS Aadhaar', fontsize = 30)
plt.xlabel('Aadhaar', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
data_pass=data.dropna(subset=['Passport'])
plt.rcParams['figure.figsize']=(5,10)
sns.barplot(x=data_pass['Passport'],y=data_pass['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS Passport', fontsize = 30)
plt.xlabel('Passport', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
"""sns.axes_style('whitegrid')
sns.catplot('Completion_Rate_Content', data=data2, aspect=3, kind='count', hue='Age', palette=['C1', 'C0']).set_ylabels('Age')"""
# Out:
# "sns.axes_style('whitegrid')\nsns.catplot('Completion_Rate_Content', data=data2, aspect=3, kind='count', hue='Age', palette=['C1', 'C0']).set_ylabels('Age')"

# %%
data_content=data.dropna(subset=['Completion_Rate_Content'])
sns.distplot(data_content['Completion_Rate_Content'], color = 'green')
plt.title('Distribution of Completion_Rate_Content', fontsize = 30)
plt.xlabel('Completion_Rate_Content', fontsize = 15)
plt.ylabel('count')
plt.show()

# %%
#data_content_form=data_content.dropna(subset=['Completion_Rate_Form'])
plt.figure(figsize=(15,6))
plt.style.use('seaborn-colorblind')
plt.grid(True, alpha=0.5)
sns.kdeplot(data.loc[data['Completion_Rate_Form'] == 0, 'Completion_Rate_Content'], label = 'Didnot filled Completion_Rate_Form')
sns.kdeplot(data.loc[data['Completion_Rate_Form'] == 1, 'Completion_Rate_Content'], label = 'Completion_Rate_Form')
plt.xlabel('Completion_Rate_Content')
#plt.xlim(Completion_Rate_Form=0)
#plt.xlim(Completion_Rate_Form=1)
plt.ylabel('Density')
plt.title('Completion of Content variation based on the from Completion',fontsize = 20);
# Out:
# C:\Users\PARTH GUPTA\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data4 = pd.read_csv('P:/TYDY/Demo_Data_Dep_Sorted.csv')
data4["State_Permanent_Address"]= data4["State_Permanent_Address"].str.lower()

# %%
data4['State_Permanent_Address'] = data4['State_Permanent_Address'].str.replace(' ', '')
data4['State_Permanent_Address'] = data4['State_Permanent_Address'].str.replace('.', '')
data4['State_Permanent_Address'] = data4['State_Permanent_Address'].str.replace('-', '')
data4['State_Permanent_Address'] = data4['State_Permanent_Address'].str.replace('', '')
data4['State_Permanent_Address'] = data4['State_Permanent_Address'].str.replace('(', '')
data4['State_Permanent_Address'] = data4['State_Permanent_Address'].str.replace(')', '')
data4['State_Permanent_Address'] = data4['State_Permanent_Address'].str.replace('{', '')
data4['State_Permanent_Address'] = data4['State_Permanent_Address'].str.replace('}', '')
data4['State_Permanent_Address'] = data4['State_Permanent_Address'].str.replace('uttarpradesh', 'up')
data4['State_Permanent_Address'] = data4['State_Permanent_Address'].str.replace('utterpradesh', 'up')
data4['State_Permanent_Address'] = data4['State_Permanent_Address'].str.replace('newdelhi', 'delhi')
#data['State_Permanent_Address'] = data['State_Permanent_Address'].str.replace('india', 'NaN')
#data['State_Permanent_Address'] = data['State_Permanent_Address'].str.replace('delh', 'delh')
#data['State_Permanent_Address'] = data['State_Permanent_Address'].str.replace('delh', 'delhi')
#data['State_Permanent_Address'] = data['State_Permanent_Address'].str.replace('delh', 'delhi')
#data['State_Permanent_Address'] = data['State_Permanent_Address'].str.replace('delh', 'delhi')
#data['State_Permanent_Address'] = data['State_Permanent_Address'].str.replace('delh', 'delhi')
data4['State_Permanent_Address'].unique()
# Out:
# array([nan, 'up', 'delhi', '19mar19', 'punjab', 'westbengal', 'rajasthan',
#        'haryana', 'uttarakhand', 'uttarpardesh', 'chhattisgarh', 'india',
#        'maharashtra', 'dehli', 'gujrat', 'kerala', 'bihar', 'orissa',
#        'madhyapradesh', 'ap', 'telangana', 'delh', 'gujarat', 'delhincr',
#        'stateuttrakhand', 'karnataka', 'manipur', 'mp', 'telengana',
#        'statebihar', 'andhrapradesh', 'j&amp', 'patna', 'stateup',
#        'ghaziabad', 'maharastra', 'uttrakhand', 'odisha', 'uttarkhand',
#        'tamilnadu', 'jharkhand', 'assam', 'andrapradesh', 'uttapradesh',
#        'ghazhiabad', 'himachalpradesh', 'puducherry', 'goa', 'karanataka',
#        'kozhikode', 'jammuandkashmir', 'uttarparadesh', '04nov19',
#        'upiwastravellingfromtundlatoagrathedistancewas29km',
#        'chattishgarh', 'uttarpradeh', 'uttrapradesh', 'newdehi',
#        'alleppey', 'uttarpradersh', 'uttarprades', 'latur', 'mahrshtra',
# ...

# %%
data4=data4.dropna(subset=['State_Permanent_Address'])
data4['State_Permanent_Address'].unique()
# Out:
# array(['up', 'delhi', '19mar19', 'punjab', 'westbengal', 'rajasthan',
#        'haryana', 'uttarakhand', 'uttarpardesh', 'chhattisgarh', 'india',
#        'maharashtra', 'dehli', 'gujrat', 'kerala', 'bihar', 'orissa',
#        'madhyapradesh', 'ap', 'telangana', 'delh', 'gujarat', 'delhincr',
#        'stateuttrakhand', 'karnataka', 'manipur', 'mp', 'telengana',
#        'statebihar', 'andhrapradesh', 'j&amp', 'patna', 'stateup',
#        'ghaziabad', 'maharastra', 'uttrakhand', 'odisha', 'uttarkhand',
#        'tamilnadu', 'jharkhand', 'assam', 'andrapradesh', 'uttapradesh',
#        'ghazhiabad', 'himachalpradesh', 'puducherry', 'goa', 'karanataka',
#        'kozhikode', 'jammuandkashmir', 'uttarparadesh', '04nov19',
#        'upiwastravellingfromtundlatoagrathedistancewas29km',
#        'chattishgarh', 'uttarpradeh', 'uttrapradesh', 'newdehi',
#        'alleppey', 'uttarpradersh', 'uttarprades', 'latur', 'mahrshtra',
# ...

# %%
for i in data4['State_Permanent_Address'].unique():
       if (data4['State_Permanent_Address'][data4['State_Permanent_Address']==i].count()<6)  :
            data4=data4[~data4.State_Permanent_Address.str.contains(i, na=False)]

# %%
data4=data4.dropna(subset=['State_Permanent_Address'])
data4['State_Permanent_Address'].value_counts()
# Out:
# up              405
# kerala          101
# maharashtra      70
# rajasthan        52
# haryana          43
# bihar            39
# odisha           17
# westbengal       17
# uttarakhand      16
# jharkhand        16
# punjab            9
# uttarpardesh      8
# tamilnadu         6
# gujarat           6
# Name: State_Permanent_Address, dtype: int64

# %%
plt.rcParams['figure.figsize']=(25,20)
sns.barplot(x=data4['State_Permanent_Address'],y=data4['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS State', fontsize = 30)
plt.xlabel('State', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize']=(15,7)
sns.barplot(x=data['Department'],y=data['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS Department', fontsize = 30)
plt.xlabel('Department', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
data['Department'].value_counts()
# Out:
# Insurance     6162
# Healthcare    2486
# Finance       2149
# Travels       1411
# Analytics     1094
# Utilities      713
# Sales          395
# HR             212
# Technology     170
# Name: Department, dtype: int64

# %%
"""g = sns.factorplot(x="Age", y="Department",
                  hue="Gender", row="Completion_Rate_Form",
                   data=data,
                   orient="h", size=10, aspect=1, palette="Set3",
                   kind="violin", split=True, cut=0, bw=.2)
plt.show()"""
# Out:
# 'g = sns.factorplot(x="Age", y="Department",\n                  hue="Gender", row="Completion_Rate_Form",\n                   data=data,\n                   orient="h", size=10, aspect=1, palette="Set3",\n                   kind="violin", split=True, cut=0, bw=.2)\nplt.show()'

# %%
plt.rcParams['figure.figsize']=(5,10)
sns.barplot(x=data['School'],y=data['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS School', fontsize = 30)
plt.xlabel('School', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize']=(5,10)
sns.barplot(x=data['Pu'],y=data['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS Pre_University', fontsize = 30)
plt.xlabel('Pu', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize']=(5,10)
sns.barplot(x=data['Graduate'],y=data['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS Graduate', fontsize = 30)
plt.xlabel('Graduate', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize']=(5,10)
sns.barplot(x=data['Post_Graduation'],y=data['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS Post_Graduation', fontsize = 30)
plt.xlabel('Post_Graduation', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
data_new=data.drop(['start_date','Pu','Work_Experience','Previous_Employer','Marital_Status','Graduate','Completion_Rate_Form','Post_Graduation','start_date','end_date','Days_worked','Number_of_Months_Exact','State_Permanent_Address','City_Permanent_Address','PAN_Card','Aadhaar','Passport'],axis=1)

# %%
data_new=data_new.dropna(subset=['Band','Gender','Age'])
data_new
# Out:
#         Age  Gender  Department Band  School  Completion_Rate_Content  \
# 182    25.0    Male     Finance   A2       1                    55.32
# 183    26.0  Female     Finance   A2       1                    40.43
# 184    24.0  Female     Finance   A1       1                    42.55
# 186    38.0  Female   Insurance   A1       1                    11.76
# 187    29.0    Male     Finance   A2       1                    55.32
# 190    23.0    Male   Insurance   A1       1                    14.89
# 191    31.0    Male   Insurance   A1       1                    57.45
# 192    27.0  Female   Utilities   A2       1                    17.02
# 194    31.0    Male   Utilities   A2       1                     0.00
# 195    27.0  Female   Utilities   A2       1                    39.13
# 198    28.0    Male   Insurance   A1       1                    19.15
# 200    23.0    Male   Utilities   A1       1                     0.00
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(data_new.corr(method='spearman'), cmap='coolwarm', annot=True)
plt.tight_layout()
plt.show()

# %%
g = sns.factorplot(x="Completion_Rate_Content", y="Band",
                  hue="Gender", row="Department",
                   data=data_new,
                   orient="h", size=10, aspect=1, palette="Set3",
                   kind="violin", split=True, cut=0, bw=.2)
plt.show()
# Out:
# C:\Users\PARTH GUPTA\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\PARTH GUPTA\Anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.rcParams['figure.figsize']=(15,7)
sns.barplot(x=data['Band'], y=data['Work_Experience'], color = 'blue')
plt.title('Work_Experience VS Band', fontsize = 30)
plt.xlabel('Band', fontsize = 15)
plt.ylabel('Work_Experience', fontsize = 15)
plt.show()

# %%
"""g = sns.factorplot(x="Number_of_Months_RoundUp", y="Band",
                  hue="Gender", row="Department",
                   data=data_age,
                   orient="h", size=10, aspect=1, palette="Set3",
                   kind="violin", split=True, cut=0, bw=.2)
plt.show()"""
# Out:
# 'g = sns.factorplot(x="Number_of_Months_RoundUp", y="Band",\n                  hue="Gender", row="Department",\n                   data=data_age,\n                   orient="h", size=10, aspect=1, palette="Set3",\n                   kind="violin", split=True, cut=0, bw=.2)\nplt.show()'
