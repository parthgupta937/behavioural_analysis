# %%
import pandas as pd
import numpy as np
hr = pd.read_csv('C:/Users/Dell/Desktop/Tydy/TYDY_DATA_1.csv')

# %%
import seaborn as sns
from matplotlib import pyplot
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import matplotlib
# %matplotlib inline

# %%
hr.head()
# Out:
#     Age Gender  Department Band  Work_Experience        Previous_Employer  \
# 0  24.0    NaN  Healthcare   A2              NaN                      NaN
# 1  32.0    NaN   Insurance  NaN              NaN                      NaN
# 2  35.0   Male   Insurance  NaN              NaN  Genpact India Pvt. Ltd.
# 3  29.0    NaN   Insurance  NaN              NaN                      NaN
# 4  26.0   Male   Insurance  NaN              NaN                      NaN
#
#                                               School  \
# 0                                                NaN
# 1                                                NaN
# 2  Kendirya Vidyalaya No-1, NH-IV, Faridabad, Har...
# 3                                                NaN
# 4                         C.M.G intermediate college
#
#                                                   Pu  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14929 entries, 0 to 14928
# Data columns (total 23 columns):
# Age                         14928 non-null float64
# Gender                      6760 non-null object
# Department                  14929 non-null object
# Band                        14474 non-null object
# Work_Experience             2853 non-null float64
# Previous_Employer           4025 non-null object
# School                      6452 non-null object
# Pu                          6480 non-null object
# Graduate                    6316 non-null object
# Post_Graduation             1790 non-null object
# Marital_Status              6760 non-null object
# Completion_Rate_Content     14929 non-null float64
# Completion_Rate_Form        14929 non-null int64
# start_date                  14929 non-null object
# end_date                    14929 non-null object
# Days_worked                 14929 non-null int64
# Number_of_Months_Exact      14929 non-null float64
# ...

# %%
hr1=hr.drop(['Days_worked'],axis=1)

# %%
hr1=hr1.drop(['start_date'],axis=1)

# %%
hr1=hr1.drop(['end_date'],axis=1)

# %%
hr1=hr1.drop(['Number_of_Months_Exact'],axis=1)
hr1=hr1.drop(['Completion_Rate_Content'],axis=1)
hr1 = hr1[hr1['Age'] <=56 ]
hr1 = hr1[hr1['Age'] >=18 ]

# %%
hr1 = hr1[~hr1.Band.str.contains("F", na=False)]

# %%
hr1 = hr1[~hr1.Band.str.contains("E2", na=False)]

# %%
hr1 = hr1[~hr1.Band.str.contains("D1", na=False)]
hr1 = hr1[~hr1.Band.str.contains("D2", na=False)]
hr1 = hr1[~hr1.Band.str.contains("E1", na=False)]

# %%
hr1 = hr1[hr1['Number_of_Months_RoundUp'] <=25]

# %%
hr2=hr.drop(['Number_of_Months_RoundUp'],axis=1)

# %%
hr1['Completion_Rate_Form'].value_counts()
# Out:
# 0    9086
# 1    5580
# Name: Completion_Rate_Form, dtype: int64

# %%
hr1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14666 entries, 0 to 14928
# Data columns (total 18 columns):
# Age                         14666 non-null float64
# Gender                      6637 non-null object
# Department                  14666 non-null object
# Band                        14215 non-null object
# Work_Experience             2777 non-null float64
# Previous_Employer           3933 non-null object
# School                      6335 non-null object
# Pu                          6362 non-null object
# Graduate                    6198 non-null object
# Post_Graduation             1740 non-null object
# Marital_Status              6637 non-null object
# Completion_Rate_Form        14666 non-null int64
# Number_of_Months_RoundUp    14666 non-null int64
# State_Permanent_Address     1285 non-null object
# City_Permanent_Address      6636 non-null object
# PAN_Card                    6637 non-null object
# Aadhaar                     6637 non-null object
# ...

# %%
hr10=hr1.dropna()

# %%
hr10['Completion_Rate_Form'].value_counts()
# Out:
# 1    249
# 0     22
# Name: Completion_Rate_Form, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.heatmap(hr1.corr(method='spearman'), cmap='coolwarm', annot=True)
plt.tight_layout()
plt.show()

# %%
hr1.describe(include='all')
# Out:
#                  Age Gender Department   Band  Work_Experience  \
# count   14666.000000   6637      14666  14215      2777.000000
# unique           NaN      2          9      6              NaN
# top              NaN   Male  Insurance     A1              NaN
# freq             NaN   4467       7608  11046              NaN
# mean       26.122256    NaN        NaN    NaN         3.628376
# std         4.294938    NaN        NaN    NaN         2.947822
# min        18.000000    NaN        NaN    NaN         0.000000
# 25%        23.000000    NaN        NaN    NaN         2.000000
# 50%        25.000000    NaN        NaN    NaN         3.000000
# 75%        28.000000    NaN        NaN    NaN         5.000000
# max        55.000000    NaN        NaN    NaN        20.000000
#
#        Previous_Employer  School    Pu                 Graduate  \
# count               3933    6335  6362                     6198
# unique              3035    5938  5895                     5126
# ...

# %%
hr['City_Permanent_Address'].value_counts()
# Out:
# Delhi                                          553
# New Delhi                                      403
# Ghaziabad                                      324
# Pune                                           208
# Noida                                          148
# Bengaluru                                      145
# Jaipur                                         110
# Bangalore                                       97
# Meerut                                          84
# New delhi                                       81
# Faridabad                                       77
# DELHI                                           66
# delhi                                           63
# Kanpur                                          57
# Lucknow                                         53
# NEW DELHI                                       50
# Aligarh                                         45
# Agra                                            45
# ...

# %%
hr1['Age'].value_counts()
# Out:
# 24.0    1826
# 23.0    1806
# 25.0    1572
# 26.0    1286
# 22.0    1155
# 27.0    1145
# 28.0    1136
# 21.0    1053
# 29.0     729
# 30.0     586
# 31.0     438
# 32.0     311
# 33.0     290
# 20.0     264
# 35.0     216
# 34.0     211
# 37.0     122
# 38.0     100
# 19.0      97
# 36.0      95
# 40.0      52
# 39.0      37
# 43.0      29
# 41.0      25
# 42.0      20
# 44.0      19
# 47.0      13
# 46.0      11
# 18.0      10
# 45.0       6
# 51.0       2
# 54.0       2
# 50.0       1
# 55.0       1
# Name: Age, dtype: int64

# %%
hr['Department'].value_counts()
# Out:
# Insurance     7709
# Healthcare    2507
# Travels       1445
# Analytics     1099
# Utilities      714
# Finance        677
# Sales          386
# HR             224
# Technology     168
# Name: Department, dtype: int64

# %%
hr['Completion_Rate_Form'].value_counts()
# Out:
# 0    9249
# 1    5680
# Name: Completion_Rate_Form, dtype: int64

# %%
hr1['Band'].value_counts()
# Out:
# A1    11046
# A2     1504
# B1      941
# B2      338
# C1      273
# C2      113
# Name: Band, dtype: int64

# %%
hr2=(hr['Band'])
hr3=hr['Completion_Rate_Form']

# %%
hr4=hr.dropna(subset=['Band'])
hr4.head()
# Out:
#       Age Gender  Department Band  Work_Experience        Previous_Employer  \
# 0    24.0    NaN  Healthcare   A2              NaN                      NaN
# 144  21.0    NaN   Insurance   A1              NaN                      NaN
# 196  23.0    NaN     Finance   A2              NaN                      NaN
# 212  29.0   Male   Insurance   A2              NaN  Capgemini India Pvt ltd
# 214  21.0    NaN   Insurance   A1              NaN                      NaN
#
#                    School                       Pu                 Graduate  \
# 0                     NaN                      NaN                      NaN
# 144                   NaN                      NaN                      NaN
# 196                   NaN                      NaN                      NaN
# 212  PVC GOVT HIGH SCHOOL  PVC GOVT JUNIOR COLLEGE  NTR GOVT DEGREE COLLEGE
# 214                   NaN                      NaN                      NaN
#
# ...

# %%
hr5=hr1.dropna(subset=['Age'])
hr5.head()
# Out:
#     Age Gender  Department Band  Work_Experience        Previous_Employer  \
# 0  24.0    NaN  Healthcare   A2              NaN                      NaN
# 1  32.0    NaN   Insurance  NaN              NaN                      NaN
# 2  35.0   Male   Insurance  NaN              NaN  Genpact India Pvt. Ltd.
# 3  29.0    NaN   Insurance  NaN              NaN                      NaN
# 4  26.0   Male   Insurance  NaN              NaN                      NaN
#
#                                               School  \
# 0                                                NaN
# 1                                                NaN
# 2  Kendirya Vidyalaya No-1, NH-IV, Faridabad, Har...
# 3                                                NaN
# 4                         C.M.G intermediate college
#
#                                                   Pu  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
hr6=hr1.dropna(subset=['Work_Experience'])
hr6['Age'].value_counts()
# Out:
# 26.0    318
# 27.0    305
# 25.0    276
# 24.0    265
# 28.0    232
# 23.0    199
# 29.0    190
# 30.0    177
# 31.0    137
# 22.0    127
# 32.0    102
# 33.0     89
# 34.0     69
# 21.0     64
# 35.0     62
# 37.0     38
# 36.0     27
# 38.0     25
# 40.0     15
# 39.0     11
# 20.0      8
# 42.0      7
# 19.0      7
# 44.0      6
# 43.0      6
# 41.0      6
# 45.0      3
# 54.0      2
# 47.0      1
# 46.0      1
# 51.0      1
# 55.0      1
# Name: Age, dtype: int64

# %%
hr5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14666 entries, 0 to 14928
# Data columns (total 18 columns):
# Age                         14666 non-null float64
# Gender                      6637 non-null object
# Department                  14666 non-null object
# Band                        14215 non-null object
# Work_Experience             2777 non-null float64
# Previous_Employer           3933 non-null object
# School                      6335 non-null object
# Pu                          6362 non-null object
# Graduate                    6198 non-null object
# Post_Graduation             1740 non-null object
# Marital_Status              6637 non-null object
# Completion_Rate_Form        14666 non-null int64
# Number_of_Months_RoundUp    14666 non-null int64
# State_Permanent_Address     1285 non-null object
# City_Permanent_Address      6636 non-null object
# PAN_Card                    6637 non-null object
# Aadhaar                     6637 non-null object
# ...

# %%
plt.figure(figsize=(15,6))
plt.style.use('seaborn-colorblind')
plt.grid(True, alpha=0.5)
sns.kdeplot(hr5.loc[hr5['Completion_Rate_Form'] == 0, 'Age'], label = 'Did not Complete the Form')
sns.kdeplot(hr5.loc[hr5['Completion_Rate_Form'] == 1, 'Age'], label = 'Completed the Form')
plt.xlabel('Age')
plt.xlim(left=0)
plt.ylabel('Density')
plt.title('Age by Form Completion Status');
# Out:
# E:\ana\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.rcParams['figure.figsize'] = (15, 7)
sns.distplot(hr5['Age'], color = 'blue')
plt.title('Distribution of Age among the Employees', fontsize = 24)
plt.xlabel('Age', fontsize = 15)
plt.ylabel('count')
plt.show()
# Out:
# E:\ana\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.axes_style('whitegrid')
sns.catplot('Age', data=hr5, aspect=3, kind='count', hue='Completion_Rate_Form', palette=['Yellow', 'C0']).set_ylabels('Number of Employees')

# %%
df_Age = pd.DataFrame(columns=["Age", "% of Defaulters"])
i=0
for field in list(hr5['Age'].unique()):
    ratio = hr5[(hr5['Age']==field)&(hr5['Completion_Rate_Form']==0)].shape[0] / hr5[hr5['Age']==field].shape[0]
    df_Age.loc[i] = (field, ratio*100)
    i += 1
    #print("In {}, the ratio of leavers is {:.2f}%".format(field, ratio*100))    

df_Age = df_Age.groupby(by="Age").sum()
df_Age.plot(kind='bar',title='Defaulters by Age in the company (%)')

# %%
plt.figure(figsize=(15,6))
plt.style.use('seaborn-colorblind')
plt.grid(True, alpha=0.5)
sns.kdeplot(hr6.loc[hr6['Completion_Rate_Form'] == 0, 'Work_Experience'], label = 'Did not Complete the Form')
sns.kdeplot(hr6.loc[hr6['Completion_Rate_Form'] == 1, 'Work_Experience'], label = 'Completed the Form')
plt.xlabel('Work_Experience')
plt.xlim(left=0)
plt.ylabel('Density')
plt.title('Work Experience by Form Completion Status');
# Out:
# E:\ana\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
hr1=hr1.drop(['Work_Experience'],axis=1)

# %%
hr1
# Out:
#         Age  Gender  Department Band  \
# 0      24.0     NaN  Healthcare   A2
# 1      32.0     NaN   Insurance  NaN
# 2      35.0    Male   Insurance  NaN
# 3      29.0     NaN   Insurance  NaN
# 4      26.0    Male   Insurance  NaN
# 5      27.0     NaN   Utilities  NaN
# 6      25.0     NaN   Insurance  NaN
# 7      37.0    Male   Insurance  NaN
# 8      27.0     NaN   Utilities  NaN
# 9      22.0     NaN   Utilities  NaN
# 10     22.0     NaN   Insurance  NaN
# 11     40.0     NaN   Insurance  NaN
# 12     31.0     NaN   Utilities  NaN
# 13     24.0     NaN   Utilities  NaN
# 14     22.0     NaN   Utilities  NaN
# 15     23.0     NaN   Insurance  NaN
# 16     23.0     NaN   Insurance  NaN
# 17     27.0  Female   Insurance  NaN
# 18     33.0     NaN   Insurance  NaN
# 19     24.0    Male   Insurance  NaN
# 20     22.0     NaN   Insurance  NaN
# 21     28.0     NaN   Insurance  NaN
# 22     23.0    Male   Utilities  NaN
# 23     34.0  Female   Insurance  NaN
# ...

# %%
hr7=hr1.dropna(subset=['Gender'])
hr7['Gender'].value_counts()
# Out:
# Male      4467
# Female    2170
# Name: Gender, dtype: int64

# %%
hr7['Completion_Rate_Form'].value_counts()
# Out:
# 1    5580
# 0    1057
# Name: Completion_Rate_Form, dtype: int64

# %%
sns.axes_style('whitegrid')
sns.catplot('Gender', data=hr7, aspect=3, kind='count', hue='Completion_Rate_Form', palette=['Red', 'C0']).set_ylabels('Number of Employees')

# %%
df_Age = pd.DataFrame(columns=["Gender", "% of Defaulters"])
i=0
for field in list(hr7['Gender'].unique()):
    ratio = hr7[(hr7['Gender']==field)&(hr7['Completion_Rate_Form']==0)].shape[0] / hr7[hr7['Gender']==field].shape[0]
    df_Age.loc[i] = (field, ratio*100)
    i += 1
    #print("In {}, the ratio of leavers is {:.2f}%".format(field, ratio*100))    

df_Age = df_Age.groupby(by="Gender").sum()
df_Age.plot(kind='bar',title='Defaulters by Gender in the company (%)')

# %%
hr8=hr1.dropna(subset=['Band'])
hr8['Band'].value_counts()
# Out:
# A1    11046
# A2     1504
# B1      941
# B2      338
# C1      273
# C2      113
# Name: Band, dtype: int64

# %%
hr8['Completion_Rate_Form'].value_counts()
# Out:
# 0    8704
# 1    5511
# Name: Completion_Rate_Form, dtype: int64

# %%
sns.axes_style('whitegrid')
sns.catplot('Band', data=hr8, aspect=3, kind='count', hue='Completion_Rate_Form', palette=['Red', 'C0']).set_ylabels('Number of Employees')

# %%
df_Age = pd.DataFrame(columns=["Band", "% of Defaulters"])
i=0
for field in list(hr8['Band'].unique()):
    ratio = hr8[(hr8['Band']==field)&(hr8['Completion_Rate_Form']==0)].shape[0] / hr8[hr8['Band']==field].shape[0]
    df_Age.loc[i] = (field, ratio*100)
    i += 1
    #print("In {}, the ratio of leavers is {:.2f}%".format(field, ratio*100))    

df_Age = df_Age.groupby(by="Band").sum()
df_Age.plot(kind='bar',title='Defaulters by Band in the company (%)')

# %%
hr1
# Out:
#         Age  Gender  Department Band  \
# 0      24.0     NaN  Healthcare   A2
# 1      32.0     NaN   Insurance  NaN
# 2      35.0    Male   Insurance  NaN
# 3      29.0     NaN   Insurance  NaN
# 4      26.0    Male   Insurance  NaN
# 5      27.0     NaN   Utilities  NaN
# 6      25.0     NaN   Insurance  NaN
# 7      37.0    Male   Insurance  NaN
# 8      27.0     NaN   Utilities  NaN
# 9      22.0     NaN   Utilities  NaN
# 10     22.0     NaN   Insurance  NaN
# 11     40.0     NaN   Insurance  NaN
# 12     31.0     NaN   Utilities  NaN
# 13     24.0     NaN   Utilities  NaN
# 14     22.0     NaN   Utilities  NaN
# 15     23.0     NaN   Insurance  NaN
# 16     23.0     NaN   Insurance  NaN
# 17     27.0  Female   Insurance  NaN
# 18     33.0     NaN   Insurance  NaN
# 19     24.0    Male   Insurance  NaN
# 20     22.0     NaN   Insurance  NaN
# 21     28.0     NaN   Insurance  NaN
# 22     23.0    Male   Utilities  NaN
# 23     34.0  Female   Insurance  NaN
# ...

# %%
hr9=hr1.dropna(subset=['Previous_Employer'])
hr9['Completion_Rate_Form'].value_counts()
# Out:
# 1    3484
# 0     449
# Name: Completion_Rate_Form, dtype: int64

# %%
hr10=hr1.dropna(subset=['School'])
hr10['Completion_Rate_Form'].value_counts()
# Out:
# 1    5487
# 0     848
# Name: Completion_Rate_Form, dtype: int64

# %%
hr11=hr1.dropna(subset=['Pu'])
hr11['Completion_Rate_Form'].value_counts()
# Out:
# 1    5507
# 0     855
# Name: Completion_Rate_Form, dtype: int64

# %%
hr12=hr1.dropna(subset=['Graduate'])
hr12['Completion_Rate_Form'].value_counts()
# Out:
# 1    5383
# 0     815
# Name: Completion_Rate_Form, dtype: int64

# %%
hr13=hr1.dropna(subset=['Post_Graduation'])
hr13['Completion_Rate_Form'].value_counts()
# Out:
# 1    1547
# 0     193
# Name: Completion_Rate_Form, dtype: int64

# %%
hr14=hr1.dropna(subset=['Marital_Status'])
hr14['Completion_Rate_Form'].value_counts()
# Out:
# 1    5580
# 0    1057
# Name: Completion_Rate_Form, dtype: int64

# %%
hr16=hr1.dropna(subset=['City_Permanent_Address'])
hr16['Completion_Rate_Form'].value_counts()
# Out:
# 1    5579
# 0    1057
# Name: Completion_Rate_Form, dtype: int64

# %%
hr15=hr1.dropna(subset=['Passport'])
hr15['Completion_Rate_Form'].value_counts()
# Out:
# 1    5580
# 0    1012
# Name: Completion_Rate_Form, dtype: int64

# %%
hr15['Number_of_Months_RoundUp'].value_counts()
# Out:
#  3     957
#  5     898
#  4     802
#  2     665
#  0     593
#  6     502
#  1     472
#  7     453
#  8     261
#  12    239
#  10    230
#  9     180
#  11    166
#  13     90
# -1      66
# -2      18
# Name: Number_of_Months_RoundUp, dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.style.use('seaborn-colorblind')
plt.grid(True, alpha=0.5)
sns.kdeplot(hr15.loc[hr15['Completion_Rate_Form'] == 0, 'Number_of_Months_RoundUp'], label = 'Did not Complete the Form')
sns.kdeplot(hr15.loc[hr15['Completion_Rate_Form'] == 1, 'Number_of_Months_RoundUp'], label = 'Completed the Form')
plt.xlabel('Number_of_Months_RoundUp')
plt.xlim(left=-7)
plt.ylabel('Density')
plt.title('Number_of_Months_RoundUp by Form Completion Status');
# Out:
# E:\ana\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.rcParams['figure.figsize'] = (15, 7)
sns.distplot(hr15['Number_of_Months_RoundUp'], color = 'blue')
plt.title('Distribution of Months worked among the Employees', fontsize = 24)
plt.xlabel('Number_of_Months_RoundUp', fontsize = 15)
plt.ylabel('count')
plt.show()
# Out:
# E:\ana\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.axes_style('whitegrid')
sns.catplot('Number_of_Months_RoundUp', data=hr15, aspect=3, kind='count', hue='Completion_Rate_Form', palette=['Red', 'C0']).set_ylabels('Number of Employees')

# %%
df_Age = pd.DataFrame(columns=["Number_of_Months_RoundUp", "% of Defaulters"])
i=0
for field in list(hr15['Number_of_Months_RoundUp'].unique()):
    ratio = hr15[(hr15['Number_of_Months_RoundUp']==field)&(hr15['Completion_Rate_Form']==0)].shape[0] / hr15[hr15['Number_of_Months_RoundUp']==field].shape[0]
    df_Age.loc[i] = (field, ratio*100)
    i += 1
    #print("In {}, the ratio of leavers is {:.2f}%".format(field, ratio*100))    

df_Age = df_Age.groupby(by="Number_of_Months_RoundUp").sum()
df_Age.plot(kind='bar',title='Defaulters by Months Worked in the company (%)')

# %%
hr_new=hr1.drop(['Previous_Employer'],axis=1)
hr_new=hr_new.drop(['School'],axis=1)
hr_new=hr_new.drop(['Pu'],axis=1)
hr_new=hr_new.drop(['Graduate'],axis=1)
hr_new=hr_new.drop(['Post_Graduation'],axis=1)
hr_new=hr_new.drop(['Marital_Status'],axis=1)
hr_new=hr_new.drop(['Passport'],axis=1)
hr_new=hr_new.drop(['Aadhaar'],axis=1)
hr_new=hr_new.drop(['PAN_Card'],axis=1)
hr_new=hr_new.drop(['City_Permanent_Address'],axis=1)

# %%
hr_new.isnull().sum()
hr_new1=hr_new.dropna()

# %%
hr_new1.count()
# Out:
# Age                         1283
# Gender                      1283
# Department                  1283
# Band                        1283
# Completion_Rate_Form        1283
# Number_of_Months_RoundUp    1283
# State_Permanent_Address     1283
# dtype: int64

# %%
sns.axes_style('whitegrid')
sns.catplot('Department', data=hr_new, aspect=3, kind='count', hue='Completion_Rate_Form', palette=['Red', 'C0']).set_ylabels('Number of Employees')

# %%
df_dep = pd.DataFrame(columns=["Department", "% of Defaulters"])
i=0
for field in list(hr_new['Department'].unique()):
    ratio = hr_new[(hr_new['Department']==field)&(hr_new['Completion_Rate_Form']==0)].shape[0] / hr_new[hr_new['Department']==field].shape[0]
    df_dep.loc[i] = (field, ratio*100)
    i += 1
    #print("In {}, the ratio of leavers is {:.2f}%".format(field, ratio*100))    

df_dep = df_dep.groupby(by="Department").sum()
df_dep.plot(kind='bar',title='Defaulters by Department in the company (%)')

# %%
hr_new
# Out:
#         Age  Gender  Department Band  Completion_Rate_Form  \
# 0      24.0     NaN  Healthcare   A2                     0
# 1      32.0     NaN   Insurance  NaN                     0
# 2      35.0    Male   Insurance  NaN                     1
# 3      29.0     NaN   Insurance  NaN                     0
# 4      26.0    Male   Insurance  NaN                     1
# 5      27.0     NaN   Utilities  NaN                     0
# 6      25.0     NaN   Insurance  NaN                     0
# 7      37.0    Male   Insurance  NaN                     1
# 8      27.0     NaN   Utilities  NaN                     0
# 9      22.0     NaN   Utilities  NaN                     0
# 10     22.0     NaN   Insurance  NaN                     0
# 11     40.0     NaN   Insurance  NaN                     0
# 12     31.0     NaN   Utilities  NaN                     0
# 13     24.0     NaN   Utilities  NaN                     0
# 14     22.0     NaN   Utilities  NaN                     0
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
hr_new['Department'].unique()
# Out:
# array(['Healthcare', 'Insurance', 'Utilities', 'Finance', 'Analytics',
#        'Travels', 'HR', 'Sales', 'Technology'], dtype=object)

# %%
plt.figure(figsize=(12,6))
sns.heatmap(hr_new.corr(method='spearman'), cmap='coolwarm', annot=True)
plt.tight_layout()
plt.show()

# %%
g = sns.factorplot(x="Age", y="Completion_Rate_Form",
                   hue="Gender", row="Department",
                    data=hr_new1,
                    orient="h", size=2, aspect=3.5, palette="Set3",
                    kind="violin", split=True, cut=0, bw=.2)
plt.show()
# Out:
# E:\ana\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# E:\ana\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# E:\ana\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
g = sns.factorplot(x="Number_of_Months_RoundUp", y="Completion_Rate_Form",
                   hue="Gender", row="Department",
                    data=hr_new1,
                    orient="h", size=2, aspect=3.5, palette="Set3",
                    kind="violin", split=True, cut=0, bw=.2)
plt.show()
# Out:
# E:\ana\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# E:\ana\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# E:\ana\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
hr_new.iloc[1][1]
# Out:
# nan

# %%
hr_new['Department']=hr_new['Department'].astype('category')
hr_new['Department']=hr_new['Department'].cat.reorder_categories(['Insurance', 'Analytics', 'Travels', 'Utilities', 'Finance','Healthcare', 'HR', 'Technology', 'Sales'])
hr_new['Department']=hr_new['Department'].cat.codes

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(hr_new['Age'],hr_new['Department'],hr_new['Completion_Rate_Form'], s=30)
plt.ylabel('Departemnt')
plt.show()

# %%
hr_new['Department'].value_counts()
# Out:
# 0    7608
# 5    2475
# 2    1421
# 1    1070
# 3     703
# 4     664
# 8     368
# 6     207
# 7     150
# Name: Department, dtype: int64
