# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter

# %%
data = pd.read_csv('P:/TYDY/Beha_Final_Data.csv')
data['Department'].unique()
# Out:
# array(['Healthcare', 'Insurance', 'Finance', 'Utilities', 'Analytics',
#        'Travels', 'HR', 'Sales', 'Technology'], dtype=object)

# %%
data['Department'].value_counts()
# Out:
# Insurance     6247
# Healthcare    2512
# Finance       2162
# Travels       1449
# Analytics     1104
# Utilities      714
# Sales          389
# HR             216
# Technology     173
# Name: Department, dtype: int64

# %%
plt.figure(figsize=(10,7))
sns.heatmap(data.corr(method='spearman'), cmap='coolwarm', annot=True)
plt.tight_layout()
plt.show()

# %%
data['Gender'].value_counts()
# Out:
# Male      4572
# Female    2207
# Name: Gender, dtype: int64

# %%
data.isnull().sum()
# Out:
# Age                                 8187
# Gender                              8187
# Department                             0
# Band                                 455
# App_Logins                             0
# Web_Logins                             0
# Total_logins                           0
# TS51                                   0
# TS50                                   0
# TS49                                   0
# TS48                                   0
# TS47                                   0
# TS46                                   0
# TS45                                   0
# TS44                                   0
# TS43                                   1
# TS42                                   1
# TS41                                   1
# TS40                                   1
# TS39                                   1
# TS38                                   1
# TS37                                   1
# TS36                                   1
# ...

# %%
data.describe(include='all')
# Out:
#                 Age Gender Department   Band    App_Logins    Web_Logins  \
# count   6779.000000   6779      14966  14511  14966.000000  14966.000000
# unique          NaN      2          9     11           NaN           NaN
# top             NaN   Male  Insurance     A1           NaN           NaN
# freq            NaN   4572       6247  11204           NaN           NaN
# mean      26.073905    NaN        NaN    NaN      5.112655      1.702258
# std        5.979358    NaN        NaN    NaN      7.470302      5.206291
# min        0.000000    NaN        NaN    NaN      0.000000      0.000000
# 25%       23.000000    NaN        NaN    NaN      0.000000      0.000000
# 50%       25.000000    NaN        NaN    NaN      2.000000      0.000000
# 75%       28.000000    NaN        NaN    NaN      7.000000      1.000000
# max      118.000000    NaN        NaN    NaN     96.000000    259.000000
#
#         Total_logins              TS51              TS50              TS49  \
# ...

# %%
data['Band'].value_counts()
# Out:
# A1    11204
# A2     1528
# B1      955
# B2      346
# C1      277
# C2      114
# D1       44
# D2       21
# E1       19
# E2        2
# F         1
# Name: Band, dtype: int64

# %%
data=data.dropna(subset=['App_Logins'])
data = data[data['App_Logins'] <=20 ]
#data = data[data['App_Logins'] >=0 ]
plt.rcParams['figure.figsize']=(15,7)
sns.distplot(data['App_Logins'], color = 'blue')
plt.title('Distribution of Age', fontsize = 30)
plt.xlabel('App_Login', fontsize = 24)
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\PARTH GUPTA\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data=data.dropna(subset=['Web_Logins'])
data = data[data['Web_Logins'] <=10 ]
#data = data[data['App_Logins'] >=0 ]
plt.rcParams['figure.figsize']=(15,7)
sns.distplot(data['Web_Logins'], color = 'blue')
plt.title('Web_Logins', fontsize = 30)
plt.xlabel('Web_Logins', fontsize = 24)
plt.ylabel('count')
plt.show()

# %%
data.groupby(['Web_Logins']).mean()
# Out:
#                   Age  App_Logins  Total_logins  Completion_Rate_Content  \
# Web_Logins
# 0           25.541483    3.203125      3.203125                11.516802
# 1           26.253793    4.906822      5.906822                25.419950
# 2           25.963570    5.507853      7.507853                29.059895
# 3           26.866213    5.510345      8.510345                31.442914
# 4           26.595041    5.761388      9.761388                32.632364
# 5           26.918367    5.644444     10.644444                33.473492
# 6           27.263636    6.127907     12.127907                42.658101
# 7           26.802548    6.406863     13.406863                42.372108
# 8           26.942149    4.929577     12.929577                41.055282
# 9           27.028037    6.076923     15.076923                54.020462
# 10          27.281690    5.172043     15.172043                52.655269
#
#             Completion_Rate_Form  Days_Worked  Months_Worked  \
# Web_Logins
# ...

# %%
plt.rcParams['figure.figsize']=(5,10)
sns.barplot(x=data['Web_Logins'],y=data['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS Web_Logins', fontsize = 30)
plt.xlabel('Web_Logins', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize']=(5,10)
sns.barplot(x=data['App_Logins'],y=data['Completion_Rate_Content'], color = 'blue')
plt.title('Completion_Rate_Content VS App_Logins', fontsize = 30)
plt.xlabel('App_Logins', fontsize = 15)
plt.ylabel('Completion_Rate_Content', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize']=(5,10)
sns.barplot(x=data['Band'],y=data['App_Logins'], color = 'blue')
plt.title('Band VS App_Logins', fontsize = 30)
plt.xlabel('App_Logins', fontsize = 15)
plt.ylabel('Band', fontsize = 15)
plt.show()

# %%
#data_age=data.dropna(subset=['Age'])
#data_age = data[data['Age'] <=50 ]
#data_age = data_age[data_age['Age'] >=18 ]
#data_age['Age'].value_counts()
#data3=data2
data1=data[~(data['Age']>55)]
data1=data[~(data['Age']<18)]
data
# Out:
#         Age  Gender  Department Band  App_Logins  Web_Logins  Total_logins  \
# 0       NaN     NaN  Healthcare   A1           0           0             0
# 1       NaN     NaN  Healthcare   A2           1           0             1
# 2       NaN     NaN   Insurance  NaN           1           0             1
# 3      35.0    Male     Finance  NaN           3           1             4
# 4       NaN     NaN     Finance  NaN           0           2             2
# 5      26.0    Male   Insurance  NaN           2           3             5
# 6       NaN     NaN   Utilities  NaN           0           0             0
# 7       NaN     NaN     Finance  NaN           0           1             1
# 8      37.0    Male     Finance  NaN           2           2             4
# 9       NaN     NaN   Utilities  NaN           0           0             0
# 10      NaN     NaN   Utilities  NaN           0           0             0
# ...

# %%
#data_age=data.dropna(subset=['Age'])
data_age = data[data['Age'] <=55 ]
data_age = data_age[data_age['Age'] >=18 ]
#data3=data2

plt.rcParams['figure.figsize']=(25,15)
sns.barplot(x=data_age['Age'],y=data_age['App_Logins'], color = 'yellow')
plt.title('Age VS App_Logins', fontsize = 30)
plt.xlabel('App_Logins', fontsize = 15)
plt.ylabel('Age', fontsize = 15)
plt.show()

# %%
data_age=data.dropna(subset=['Age'])
data_age = data_age[data_age['Age'] <=55 ]
data_age = data_age[data_age['Age'] >=18 ]
#data3=data2

plt.rcParams['figure.figsize']=(25,15)
sns.barplot(x=data_age['Age'],y=data_age['Web_Logins'], color = 'blue')
plt.title('Band VS Web_Logins', fontsize = 30)
plt.xlabel('Web_Logins', fontsize = 15)
plt.ylabel('Age', fontsize = 15)
plt.show()

# %%
data_age=data.dropna(subset=['Age'])
data_age = data_age[data_age['Age'] <=55 ]
data_age = data_age[data_age['Age'] >=18 ]
#data3=data2

plt.rcParams['figure.figsize']=(25,15)
sns.barplot(x=data_age['Age'],y=data_age['App_Logins'], color = 'yellow')
sns.barplot(x=data_age['Age'],y=data_age['Web_Logins'], color = 'blue')

plt.title('Web_Logins VS App_Logins', fontsize = 30)
plt.xlabel('App_Logins', fontsize = 15)
plt.ylabel('Web_Logins', fontsize = 15)
plt.bar('Age', 'Web_Logins')

plt.show()

# %%
data_age=data.dropna(subset=['Age'])
data_age = data_age[data_age['Age'] <=55 ]
data_age = data_age[data_age['Age'] >=18 ]
#data3=data2

plt.rcParams['figure.figsize']=(25,10)
sns.regplot(x=data_age['Age'],y=data_age['App_Logins'], x_estimator=np.mean, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=None, n_boot=1000, units=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=False, dropna=True, x_jitter=None, y_jitter=None, label='Red', color='red', marker='o', scatter_kws=None, line_kws=None, ax=None)
sns.regplot(x=data_age['Age'],y=data_age['Web_Logins'], x_estimator=np.mean, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=None, n_boot=1000, units=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=False, dropna=True, x_jitter=None, y_jitter=None, label='Blue', color='blue', marker='o', scatter_kws=None, line_kws=None, ax=None)

#sns.regplot(x=data_age['Age'],y=data_age['Web_Logins'], color = 'blue', ci=None)

plt.title('Web_Logins VS App_Logins', fontsize = 30)
plt.xlabel('Age', fontsize = 15)
plt.ylabel('Frequency', fontsize = 15)
#plt.bar('Age', 'Web_Logins')

plt.show()

# %%
sns.axes_style('whitegrid')
sns.catplot('Web_Logins', data=data, aspect=3, kind='count', hue='Gender', palette=['C1', 'C0']).set_ylabels('Number of Employees')

# %%
plt.rcParams['figure.figsize']=(20,10)
df_Gen = pd.DataFrame(columns=["Gender", "% of People"])
i=0
for field in list(data1['Gender'].unique()):
    ratio= data1[data1['Gender'] == field].shape[0]/ data1.shape[0]
    df_Gen.loc[i] = (field, ratio*100)
    i +=1

df_Gen.plot(kind='bar',title='Logged_after_which_reminder (%)',left=-2)

# %%
sns.axes_style('whitegrid')
sns.catplot('App_Logins', data=data, aspect=3, kind='count', hue='Gender', palette=['C1', 'C0']).set_ylabels('Number of Employees')

# %%
sns.axes_style('whitegrid')
sns.catplot('Total_logins', data=data, aspect=3, kind='count', hue='Gender', palette=['C1', 'C0']).set_ylabels('Number of Employees')

# %%
plt.rcParams['figure.figsize']=(2,5)
sns.barplot(x=data1['Completion_Rate_Form'],y=data1['Total_logins'], color = 'blue')
plt.title('Completion_Rate_Form VS Total_logins', fontsize = 30)
plt.xlabel('Completion_Rate_Form', fontsize = 15)
plt.ylabel('Total_logins', fontsize = 15, rotation=90)
plt.show()

# %%
plt.rcParams['figure.figsize']=(25,5)
sns.barplot(y=data1['Completion_Rate_Content'],x=data1['Total_logins'], color = 'blue')
sns.regplot(y=data1['Completion_Rate_Content'],x=data1['Total_logins'], x_estimator=np.mean, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=None, n_boot=1000, units=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=False, dropna=True, x_jitter=None, y_jitter=None, label='Red', color='red', marker='o', scatter_kws=None, line_kws=None, ax=None)

plt.title('Completion_Rate_Form VS Total_logins', fontsize = 30)
plt.xlabel('Completion_Rate_Form', fontsize = 15)
plt.ylabel('Total_logins', fontsize = 15, rotation=90)
plt.show()

# %%
plt.rcParams['figure.figsize']=(20,7)
sns.barplot(x=data['Department'],y=data['App_Logins'], color = 'yellow')
sns.barplot(x=data['Department'],y=data['Web_Logins'], color = 'red')
plt.title('Total_logins VS Department', fontsize = 30)
plt.xlabel('Department', fontsize = 15)
plt.ylabel('Total_logins', fontsize = 15)
plt.show()

# %%
data_dep=data.dropna(subset=['Department'])
#data_month = data_month[data_month['Number_of_Months_RoundUp'] <=25 ]
#data_month = data_month[data_month['Number_of_Months_RoundUp'] >=0 ]

plt.rcParams['figure.figsize']=(20,7)
sns.barplot(x=data_dep['Department'],y=data_dep['Total_logins'], color = 'blue')
plt.title('Total_logins VS Department', fontsize = 30)
plt.xlabel('Department', fontsize = 15)
plt.ylabel('Total_logins', fontsize = 15)
plt.show()

# %%
data_band=data.dropna(subset=['Band'])
#data_month = data_month[data_month['Number_of_Months_RoundUp'] <=25 ]
#data_month = data_month[data_month['Number_of_Months_RoundUp'] >=0 ]

plt.rcParams['figure.figsize']=(20,7)
sns.barplot(x=data_band['Band'],y=data_band['App_Logins'], color = 'yellow')

sns.barplot(x=data_band['Band'],y=data_band['Web_Logins'], color = 'red')
plt.title('Total_logins VS Band', fontsize = 30)
plt.xlabel('Band', fontsize = 15)
plt.ylabel('Total_logins', fontsize = 15)
plt.show()

# %%
data.groupby('Band').mean()
# Out:
#             Age  App_Logins  Web_Logins  Total_logins  \
# Band
# A1    25.319138    3.722212    0.648016      4.370228
# A2    26.539062    5.501910    2.009167      7.511077
# B1    27.757033    4.569083    2.774282      7.343365
# B2    30.022472    3.906250    3.364583      7.270833
# C1    30.958333    4.388626    3.459716      7.848341
# C2    33.538462    4.044944    3.303371      7.348315
# D1    36.250000    3.206897    3.793103      7.000000
# D2    40.600000    3.666667    5.750000      9.416667
# E1    40.000000    3.928571    2.500000      6.428571
# E2          NaN    2.000000    4.500000      6.500000
# F           NaN    0.000000    5.000000      5.000000
#
#       Completion_Rate_Content  Completion_Rate_Form  Days_Worked  \
# Band
# A1                  14.802102             29.810043   159.757664
# A2                  28.917074             59.358289   152.566845
# B1                  32.991368             49.794802   147.673051
# ...

# %%
data.groupby('Department').mean()
# Out:
#                   Age  App_Logins  Web_Logins  Total_logins  \
# Department
# Analytics   25.413793    5.249037    3.621309      8.870347
# Finance     26.069669    5.799897    1.746914      7.546811
# HR          27.560606    3.689266    1.666667      5.355932
# Healthcare  24.255814    2.389209    0.428336      2.817545
# Insurance   26.307204    3.659983    0.636057      4.296040
# Sales       29.786096    4.993464    2.797386      7.790850
# Technology  32.300000    3.791367    3.705036      7.496403
# Travels     24.899145    4.111610    0.725843      4.837453
# Utilities   25.761194    3.202550    0.614731      3.817280
#
#             Completion_Rate_Content  Completion_Rate_Form  Days_Worked  \
# Department
# Analytics                 32.356855             68.035944   151.268293
# Finance                   27.083524             63.374486   164.911523
# HR                        21.274746             31.638418   161.491525
# ...

# %%
data.groupby('Gender').mean()
# Out:
#               Age  App_Logins  Web_Logins  Total_logins  \
# Gender
# Female  25.449117    6.965213    1.877985      8.843198
# Male    26.399789    7.333158    1.913616      9.246774
#
#         Completion_Rate_Content  Completion_Rate_Form  Days_Worked  \
# Gender
# Female                29.012025             82.917965   154.677051
# Male                  30.076750             81.722412   155.370029
#
#         Months_Worked  Months_Worked_Roundoff  Hour_Form_Completed    Minutes  \
# Gender
# Female       5.076708                5.057632            10.790232  24.961059
# Male         5.099186                5.079010            10.695134  23.902555
#
#         Minutes/60  Minutes_Roundup  Total_Hours  Whether_logged_in  \
# Gender
# Female    0.416018         0.425753     9.372793           0.387046
# Male      0.398376         0.404793     9.145115           0.389558
#
#         Logged_or_not
# Gender
# Female      90.837283
# Male        91.914324

# %%
#data.groupby('Whether_logged_in').mean()
data.groupby('Whether_logged_in').mean()
# Out:
#                          Age  App_Logins  Web_Logins  Total_logins  \
# Whether_logged_in
# -1.0               25.718487    1.540733    0.397403      1.938136
#  0.0               25.950416    5.271492    1.303296      6.574789
#  1.0               26.121771    4.764706    1.292220      6.056926
#  2.0               26.910959    3.972997    1.263937      5.236934
#  3.0               26.606635    3.266436    0.989619      4.256055
#  4.0               26.186047    2.778481    1.094937      3.873418
#
#                    Completion_Rate_Content  Completion_Rate_Form  Days_Worked  \
# Whether_logged_in
# -1.0                              6.153633             10.616090   171.619399
#  0.0                             23.916449             49.047540   163.190658
#  1.0                             22.242872             41.239722   147.599620
#  2.0                             20.804172             31.794425   163.084495
# ...

# %%
import datetime
from datetime import timedelta
 
#datetimeFormat = '%Y-%m-%d %H:%M.%f'
datetimeFormat = '%d-%m-%Y %H:%M'
arr = []
for i in range(2, 14000):
    date1 = data['TS40'][i]
    date2 = data['TS41'][i]
    diff = datetime.datetime.strptime(date1, datetimeFormat)-datetime.datetime.strptime(date2, datetimeFormat)
    Days_between = diff.days
    #arr[i] = Days_between
    print(i , Days_between)
    
     
'''


if Days_between < 2 :
        print(diff.days)
    else:
        i=i+1



print("Difference:", diff)
print("Days:", diff.days)
print("Microseconds:", diff.microseconds)
print("Seconds:", diff.seconds)'''
# Out:
# 2 -1
# 3 -1
# 4 -2
# 5 -1
# 6 -1
# 7 -1
# 8 -1
# 9 0
# 10 -1
# 11 -1
# 12 -1
# 13 -1
# 14 0
# 15 -1
# 16 389
# 17 0
# 18 -1
# 19 0
# 20 254
# 21 154
# 22 161
# 23 0
# 24 -1
# 25 0
# 26 1
# 27 0
# 28 -1
# 29 280
# 30 280
# 31 0
# 32 227
# 33 -1
# 34 0
# 35 0
# 36 335
# 37 -1
# 38 0
# 39 236
# 40 -1
# 41 298
# 42 -2
# 43 0
# 44 -1
# 45 -1
# 46 20
# 47 0
# 48 -1
# 49 223
# 50 287
# 51 236
# 52 112
# 53 -5
# 54 0
# 55 0
# 56 0
# 57 0
# 58 266
# 59 0
# 60 228
# 61 0
# 62 0
# 63 0
# 64 258
# 65 189
# 66 -1
# 67 222
# 68 -1
# 69 -1
# 70 0
# 71 -1
# 72 0
# 73 293
# 74 0
# 75 0
# 76 -1
# 77 -1
# 78 -1
# 79 0
# 80 -1
# 81 -3
# 82 -1
# 83 0
# 84 0
# 85 -1
# 86 -1
# 87 0
# 88 0
# 89 0
# 90 0
# 91 0
# 92 -1
# 93 0
# 94 0
# 95 0
# 96 228
# 97 0
# 98 0
# 99 0
# 100 0
# 101 0
# 102 0
# 103 -1
# 104 197
# 105 -1
# 106 0
# 107 0
# 108 -1
# 109 0
# 110 0
# 111 0
# 112 0
# 113 0
# 114 -1
# 115 0
# 116 -1
# 117 -1
# 118 1
# 119 0
# 120 -1
# 121 0
# 122 0
# 123 -1
# 124 0
# 125 -1
# 126 -1
# 127 -1
# ...

# %%
data.values.reshape(13749, 73)
